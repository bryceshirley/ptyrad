# %% [markdown]
# # Quick example for PtyRAD
#
# - Created with PtyRAD 0.1.0b8
# - Requires PtyRAD >= 0.1.0b8
# - Latest demo params files / scripts: https://github.com/chiahao3/ptyrad/tree/main/demo
# - Documentation: https://ptyrad.readthedocs.io/en/latest/
# - PtyRAD paper: https://doi.org/10.1093/mam/ozaf070
# - PtyRAD arXiv: https://arxiv.org/abs/2505.07814
# - Zenodo record: https://doi.org/10.5281/zenodo.15273176
# - Box folder: https://cornell.box.com/s/n5balzf88jixescp9l15ojx7di4xn1uo
# - Youtube channel: https://www.youtube.com/@ptyrad_official
#
# **Before running this notebook, you must first follow the instruction in `README.md` to:**
# 1. Create the Python environment with all dependant Python packages like PyTorch
# 2. Activate that python environment
# 3. Install `ptyrad` package into your activated Python environement (only need to install once)
# 4. Download the demo data into `demo/data/` from the `demo/data/data_url.txt`
#
# > Note: This notebook is designed for "ease of operation with the solver class `PtyRADSolver`", both "reconstruction" and "hypertune" modes are supported.
#
# Author: Chia-Hao Lee, cl2696@cornell.edu

# %%
import os

# Change this to the ABSOLUTE PATH to the demo/ folder so you can correctly access data/ and params/
work_dir = "../"  # Leave this as-is if you're running the notebook from the `ptyrad/demo/scripts/` folder, this will change it back to demo/

os.chdir(work_dir)
print("Current working dir: ", os.getcwd())
# The printed working dir should be ".../ptyrad/demo" to locate the demo params files easily
# Note that the output/ directory will be automatically generated under your working directory
# Out:
# Current working dir:  /home/dnz75396/ptyrad/demo

# %%
from ptyrad.load import load_params
from ptyrad.reconstruction import PtyRADSolver
from ptyrad.utils import CustomLogger, print_system_info, set_gpu_device

logger = CustomLogger(
    log_file="ptyrad_log.txt", log_dir="auto", prefix_time="datetime", show_timestamp=True
)

# All the following params files are provided in demo/params/ and we're using relative path here
# So if you change the working directory, or have moved params files around, you'll have to provide absolute path to the params file

# params_path = "params/tBL_WSe2_reconstruct_minimal.yml"
# params_path = "params/tBL_WSe2_reconstruct.yml"
params_path = "params/PSO_reconstruct.yml"
# params_path = (
#     "params/tBL_WSe2_tuned.yml"  # This will run PtyRAD with the hyperparameter tuning mode
# )

print_system_info()

# We enable validation to auto-fill defaults and check parameter consistency since PtyRAD 0.1.0b8
# If you run into issues with validation (e.g., false positives or unexpected errors),
# you can temporarily disable it by setting `validate=False` and prepare a fully complete params file yourself.
# If this happens, please report the bug so we can improve the validation logic.
params = load_params(params_path, validate=True)

print("Loaded params: ", params)
device = set_gpu_device(
    gpuid=0
)  # Pass in `gpuid = None` if you don't have access to a CUDA-compatible GPU. Note that running PtyRAD with CPU would be much slower than on GPU.

ptycho_solver = PtyRADSolver(params, device=device, logger=logger)
# Out:
# 2026-06-11 14:46:48,384 - ### PtyRAD Logger configuration ###
# 2026-06-11 14:46:48,385 - log_file       = 'ptyrad_log.txt'. If log_file = None, no log file will be created.
# 2026-06-11 14:46:48,386 - log_dir        = 'auto'. If log_dir = 'auto', then log will be saved to `output_path` or 'logs/'.
# 2026-06-11 14:46:48,386 - flush_file     = True. Automatically set to True if `log_file is not None`
# 2026-06-11 14:46:48,387 - prefix_time    = datetime. If true, preset strings ('date', 'time', 'datetime'), or a string of time format, a datetime str is prefixed to the `log_file`.
# 2026-06-11 14:46:48,387 - prefix_jobid   = '0'. If not 0, it'll be prefixed to the log file. This is used for hypertune mode with multiple GPUs.
# 2026-06-11 14:46:48,388 - append_to_file = True. If true, logs will be appended to the existing file. If false, the log file will be overwritten.
# 2026-06-11 14:46:48,388 - show_timestamp = True. If true, the printed information will contain a timestamp.
# 2026-06-11 14:46:48,389 -
# 2026-06-11 14:46:48,389 - ### System information ###
# 2026-06-11 14:46:48,390 - Platform: Linux-6.8.0-111-generic-x86_64-with-glibc2.39
# 2026-06-11 14:46:48,390 - Operating System: Linux 6.8.0-111-generic
# 2026-06-11 14:46:48,390 - OS Version: #111-Ubuntu SMP PREEMPT_DYNAMIC Sat Apr 11 23:16:02 UTC 2026
# 2026-06-11 14:46:48,392 - Machine: x86_64
# 2026-06-11 14:46:48,392 - Processor: x86_64
# 2026-06-11 14:46:48,393 - Available CPU cores: 16
# 2026-06-11 14:46:48,393 - Total Memory: 118.01 GB
# 2026-06-11 14:46:48,394 - Available Memory: 113.81 GB
# 2026-06-11 14:46:48,394 -
# 2026-06-11 14:46:48,395 - ### GPU information ###
# 2026-06-11 14:46:48,772 - CUDA Available: True
# 2026-06-11 14:46:48,772 - CUDA Version: 12.8
# 2026-06-11 14:46:48,787 - Available CUDA GPUs: ['NVIDIA RTX A4000']
# 2026-06-11 14:46:48,788 - CUDA Compute Capability: ['8.6']
# 2026-06-11 14:46:48,788 -   INFO: For torch.compile with Triton, you'll need CUDA GPU with Compute Capability >= 7.0.
# 2026-06-11 14:46:48,789 -         In addition, Triton does not directly support Windows.
# 2026-06-11 14:46:48,789 -         For Windows users, please follow the instruction and download `triton-windows` from https://github.com/woct0rdho/triton-windows.
# 2026-06-11 14:46:48,903 - MIG (Multi-Instance GPU) mode = False
# 2026-06-11 14:46:48,903 -   INFO: MIG splits a physical GPU into multiple GPU slices, but multiGPU does not support these MIG slices.
# 2026-06-11 14:46:48,904 -         In addition, multiGPU is currently only available on Linux due to the limited NCCL support.
# 2026-06-11 14:46:48,904 -       -> If you're doing normal reconstruction/hypertune, you can safely ignore this.
# 2026-06-11 14:46:48,905 -       -> If you want to do multiGPU, you must provide multiple 'full' GPUs that are not in MIG mode.
# 2026-06-11 14:46:48,905 -
# 2026-06-11 14:46:48,906 - ### Python information ###
# 2026-06-11 14:46:48,907 - Python Executable: /home/dnz75396/ptyrad/.venv/bin/python
# 2026-06-11 14:46:48,907 - Python Version: 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]
# 2026-06-11 14:46:48,908 -
# 2026-06-11 14:46:48,908 - ### Packages information ###
# 2026-06-11 14:46:48,909 - Numpy Version (metadata): 2.4.3
# 2026-06-11 14:46:48,911 - PyTorch Version (metadata): 2.10.0
# 2026-06-11 14:46:48,912 - Optuna Version (metadata): 4.8.0
# 2026-06-11 14:46:48,913 - Accelerate Version (metadata): 1.13.0
# 2026-06-11 14:46:48,914 - PtyRAD Version (ptyrad/__init__.py): 0.1.0b12
# 2026-06-11 14:46:48,915 - PtyRAD is located at: /home/dnz75396/ptyrad/src/ptyrad/__init__.py
# 2026-06-11 14:46:48,915 -
# 2026-06-11 14:46:48,916 - ### Loading params file ###
# 2026-06-11 14:46:48,980 - Success! Loaded .yml file path = params/PSO_reconstruct.yml
# 2026-06-11 14:46:48,981 - WARNING: For constraint_params, 'freq' is depracated since PtyRAD v0.1.0b11 and is automatically converted to 'step'.
# 2026-06-11 14:46:49,132 - validate = True: Filling defaults and validating the params file...
# 2026-06-11 14:46:49,134 - Success! Params file validated and defaults applied.
# 2026-06-11 14:46:49,134 -
# 2026-06-11 14:46:49,135 - ### Setting GPU Device ###
# 2026-06-11 14:46:49,135 - Selected GPU device: cuda:0 (NVIDIA RTX A4000)
# 2026-06-11 14:46:49,136 -
# 2026-06-11 14:46:49,137 - ### Initializing Initializer ###
# 2026-06-11 14:46:49,137 - init_params are displayed below:
# 2026-06-11 14:46:49,138 -   random_seed: None
# 2026-06-11 14:46:49,138 -   probe_illum_type: electron
# 2026-06-11 14:46:49,139 -   probe_kv: 300.0
# 2026-06-11 14:46:49,139 -   probe_conv_angle: 21.4
# 2026-06-11 14:46:49,140 -   probe_defocus: -200.0
# 2026-06-11 14:46:49,140 -   probe_c3: 0.0
# 2026-06-11 14:46:49,140 -   probe_c5: 0.0
# 2026-06-11 14:46:49,141 -   beam_kev: None
# 2026-06-11 14:46:49,141 -   probe_dRn: None
# 2026-06-11 14:46:49,141 -   probe_Rn: None
# 2026-06-11 14:46:49,142 -   probe_D_H: None
# 2026-06-11 14:46:49,142 -   probe_D_FZP: None
# 2026-06-11 14:46:49,143 -   probe_Ls: None
# 2026-06-11 14:46:49,143 -   meas_Npix: 256
# 2026-06-11 14:46:49,143 -   pos_N_scans: 4096
# 2026-06-11 14:46:49,144 -   pos_N_scan_slow: 64
# 2026-06-11 14:46:49,144 -   pos_N_scan_fast: 64
# 2026-06-11 14:46:49,145 -   pos_scan_step_size: 0.41
# 2026-06-11 14:46:49,145 -   meas_calibration: {'mode': 'fitRBF', 'value': None}
# 2026-06-11 14:46:49,145 -   probe_pmode_max: 4
# 2026-06-11 14:46:49,146 -   probe_pmode_init_pows: [0.02]
# 2026-06-11 14:46:49,146 -   obj_omode_max: 1
# 2026-06-11 14:46:49,147 -   obj_omode_init_occu: {'occu_type': 'uniform', 'init_occu': None}
# 2026-06-11 14:46:49,147 -   obj_Nlayer: 21
# 2026-06-11 14:46:49,147 -   obj_slice_thickness: 10.0
# 2026-06-11 14:46:49,148 -   meas_permute: None
# 2026-06-11 14:46:49,149 -   meas_reshape: None
# 2026-06-11 14:46:49,149 -   meas_flipT: None
# 2026-06-11 14:46:49,149 -   meas_crop: [None, None, [68, 188], [68, 188]]
# 2026-06-11 14:46:49,150 -   meas_pad: {'mode': 'on_the_fly', 'padding_type': 'power', 'target_Npix': 256, 'value': 0.0, 'threshold': 70}
# 2026-06-11 14:46:49,150 -   meas_resample: {'mode': None, 'scale_factors': [2.0, 2.0]}
# 2026-06-11 14:46:49,151 -   meas_add_source_size: None
# 2026-06-11 14:46:49,151 -   meas_add_detector_blur: None
# 2026-06-11 14:46:49,151 -   meas_remove_neg_values: {'mode': 'clip_neg', 'value': None, 'force': False}
# 2026-06-11 14:46:49,152 -   meas_normalization: {'mode': 'max_at_one', 'value': None}
# 2026-06-11 14:46:49,152 -   meas_add_poisson_noise: None
# 2026-06-11 14:46:49,152 -   meas_export: None
# 2026-06-11 14:46:49,157 -   probe_permute: None
# 2026-06-11 14:46:49,157 -   probe_z_shift: None
# 2026-06-11 14:46:49,158 -   pos_scan_flipT: None
# 2026-06-11 14:46:49,158 -   pos_scan_affine: None
# 2026-06-11 14:46:49,159 -   pos_scan_rand_std: 0.15
# 2026-06-11 14:46:49,159 -   obj_z_crop: None
# 2026-06-11 14:46:49,160 -   obj_z_pad: None
# 2026-06-11 14:46:49,160 -   obj_z_resample: None
# 2026-06-11 14:46:49,161 -   meas_source: file
# 2026-06-11 14:46:49,161 -   meas_params: {'path': 'data/PSO/sample_data_PrScO3.mat', 'key': 'dp', 'shape': None, 'offset': None, 'gap': None}
# 2026-06-11 14:46:49,162 -   probe_source: simu
# 2026-06-11 14:46:49,162 -   probe_params: None
# 2026-06-11 14:46:49,163 -   pos_source: simu
# 2026-06-11 14:46:49,163 -   pos_params: None
# 2026-06-11 14:46:49,164 -   obj_source: simu
# 2026-06-11 14:46:49,164 -   obj_params: None
# 2026-06-11 14:46:49,164 -   tilt_source: simu
# 2026-06-11 14:46:49,165 -   tilt_params: {'tilt_type': 'all', 'init_tilts': [[0.0, 0.0]]}
# 2026-06-11 14:46:49,165 -
# 2026-06-11 14:46:49,166 - ### Initializing cache ###
# 2026-06-11 14:46:49,167 - use_cached_obj   = False
# 2026-06-11 14:46:49,167 - use_cached_probe = False
# 2026-06-11 14:46:49,168 - use_cached_pos   = False
# 2026-06-11 14:46:49,168 -
# 2026-06-11 14:46:49,168 - ### Initializing measurements ###
# 2026-06-11 14:46:49,169 - Loading measurements from source = 'file'
# 2026-06-11 14:46:49,169 - Detected measurement file type = '.mat'
# 2026-06-11 14:46:49,170 - Detected .mat v7.3 (HDF5 format). Delegating to `load_hdf5`.
# Loaded params:  {'init_params': {'random_seed': None, 'probe_illum_type': 'electron', 'probe_kv': 300.0, 'probe_conv_angle': 21.4, 'probe_defocus': -200.0, 'probe_c3': 0.0, 'probe_c5': 0.0, 'beam_kev': None, 'probe_dRn': None, 'probe_Rn': None, 'probe_D_H': None, 'probe_D_FZP': None, 'probe_Ls': None, 'meas_Npix': 256, 'pos_N_scans': 4096, 'pos_N_scan_slow': 64, 'pos_N_scan_fast': 64, 'pos_scan_step_size': 0.41, 'meas_calibration': {'mode': 'fitRBF', 'value': None}, 'probe_pmode_max': 4, 'probe_pmode_init_pows': [0.02], 'obj_omode_max': 1, 'obj_omode_init_occu': {'occu_type': 'uniform', 'init_occu': None}, 'obj_Nlayer': 21, 'obj_slice_thickness': 10.0, 'meas_permute': None, 'meas_reshape': None, 'meas_flipT': None, 'meas_crop': [None, None, [68, 188], [68, 188]], 'meas_pad': {'mode': 'on_the_fly', 'padding_type': 'power', 'target_Npix': 256, 'value': 0.0, 'threshold': 70}, 'meas_resample': {'mode': None, 'scale_factors': [2.0, 2.0]}, 'meas_add_source_size': None, 'meas_add_detector_blur': None, 'meas_remove_neg_values': {'mode': 'clip_neg', 'value': None, 'force': False}, 'meas_normalization': {'mode': 'max_at_one', 'value': None}, 'meas_add_poisson_noise': None, 'meas_export': None, 'probe_permute': None, 'probe_z_shift': None, 'pos_scan_flipT': None, 'pos_scan_affine': None, 'pos_scan_rand_std': 0.15, 'obj_z_crop': None, 'obj_z_pad': None, 'obj_z_resample': None, 'meas_source': 'file', 'meas_params': {'path': 'data/PSO/sample_data_PrScO3.mat', 'key': 'dp', 'shape': None, 'offset': None, 'gap': None}, 'probe_source': 'simu', 'probe_params': None, 'pos_source': 'simu', 'pos_params': None, 'obj_source': 'simu', 'obj_params': None, 'tilt_source': 'simu', 'tilt_params': {'tilt_type': 'all', 'init_tilts': [[0.0, 0.0]]}}, 'hypertune_params': {'if_hypertune': False, 'collate_results': True, 'append_params': True, 'n_trials': 5, 'timeout': None, 'sampler_params': {'name': 'TPESampler', 'configs': {'multivariate': True, 'group': True, 'constant_liar': True}}, 'pruner_params': {'name': 'HyperbandPruner', 'configs': {'min_resource': 5, 'reduction_factor': 2}}, 'storage_path': 'sqlite:///hypertune.sqlite3', 'study_name': 'PSO', 'error_metric': 'loss', 'frc_split_method': 'binomial', 'tune_params': {'optimizer': {'state': False, 'suggest': 'cat', 'kwargs': {'choices': ['Adam', 'AdamW', 'RMSprop', 'SGD'], 'optim_configs': {}}}, 'batch_size': {'state': False, 'suggest': 'int', 'kwargs': {'low': 16, 'high': 512, 'log': True}}, 'plr': {'state': False, 'suggest': 'cat', 'kwargs': {'choices': [0.01, 0.0001, 0.0001]}}, 'oalr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'oplr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'slr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'tlr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'dzlr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'dx': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.14, 'high': 0.16, 'step': None, 'log': False}}, 'pmode_max': {'state': False, 'suggest': 'int', 'kwargs': {'low': 1, 'high': 8, 'step': 1, 'log': False}}, 'conv_angle': {'state': False, 'suggest': 'float', 'kwargs': {'low': 24, 'high': 26, 'step': 1, 'log': False}}, 'defocus': {'state': False, 'suggest': 'float', 'kwargs': {'low': -50, 'high': 50, 'step': 0.1, 'log': False}}, 'z_shift': {'state': False, 'suggest': 'float', 'kwargs': {'low': -50, 'high': 50, 'step': 10}}, 'c3': {'state': False, 'suggest': 'float', 'kwargs': {'low': 4000, 'high': 10000, 'step': None, 'log': False}}, 'c5': {'state': False, 'suggest': 'float', 'kwargs': {'low': 50000, 'high': 100000, 'step': 5000, 'log': False}}, 'Nlayer': {'state': False, 'suggest': 'int', 'kwargs': {'low': 1, 'high': 8, 'step': 1, 'log': False}}, 'dz': {'state': F ...
# 2026-06-11 14:46:53,049 - Success! Loaded .hdf5 file with key = 'dp' from path = 'data/PSO/sample_data_PrScO3.mat'
# 2026-06-11 14:46:53,051 - Imported .hdf5 data shape = (4096, 256, 256)
# 2026-06-11 14:46:53,052 - Imported .hdf5 data type = float64
# 2026-06-11 14:46:53,342 - Casting measurements dtype to float32 (single precision) for computational efficiency.
# 2026-06-11 14:46:53,343 - Imported meausrements shape / dtype = (4096, 256, 256), dtype = float32
# 2026-06-11 14:46:53,532 - Imported meausrements int. statistics (min, mean, max) = (0.0000, 3.1329, 416.8463)
# 2026-06-11 14:46:53,595 - Reshaping measurements into (64, 64, 256, 256) for cropping
# 2026-06-11 14:46:53,596 - Cropping axis ky from 68 to 188
# 2026-06-11 14:46:53,597 - Cropping axis kx from 68 to 188
# 2026-06-11 14:46:53,597 - Cropped measurements have shape (N_slow, N_fast, ky, kx) = (64, 64, 120, 120)
# 2026-06-11 14:46:53,597 - Update (Npix, N_scans, N_scan_slow, N_scan_fast) after the measurements cropping
# 2026-06-11 14:46:53,598 - Reshape measurements back to (N, ky, kx) = (4096, 120, 120)
# 2026-06-11 14:46:53,649 - No negative values found in measurements. Skipping non-neg correction.
# 2026-06-11 14:46:53,650 - Normalizing measurements with mode = 'max_at_one' and value = 'None'
# 2026-06-11 14:46:53,700 - Normalizing by max of the 2D mean pattern intensity: 91.590782
# 2026-06-11 14:46:53,850 - meausrements int. statistics (min, mean, max) = (0.0000, 0.1555, 4.5512)
# 2026-06-11 14:46:53,851 - Padding measurements with mode='on_the_fly', padding_type='power', target_Npix=256
# 2026-06-11 14:46:53,866 - Using percentile = 70.00% to create an one-hot mask for measurements amplitude background fitting
# 2026-06-11 14:46:53,867 - The mask has roughly 37.08 px in radius, or 0.62 of the distance from center to edge of the image
# 2026-06-11 14:46:53,941 - Fitted a = 23.8710, b = 1.3862 for power law decay: y = a*r^-b
# 2026-06-11 14:46:53,943 - Original meas int sum = 2239.2568, padded region int sum = 80.0559, or 3.58% more intensity after padding.
# 2026-06-11 14:46:53,944 - This percentage should be ideally less than 5%, or you should set a lower threshold to exclude more central region.
# 2026-06-11 14:46:53,944 - Update Npix after the measurements padding
# 2026-06-11 14:46:53,964 - No negative values found in measurements. Skipping non-neg correction.
# 2026-06-11 14:46:53,985 - Adjusting `meas_avg_sum` by adding 80.0559 for on_the_fly meas padding
# 2026-06-11 14:46:54,034 - meausrements int. statistics (min, mean, max) = (0.0000, 0.1555, 4.5512)
# 2026-06-11 14:46:54,034 - measurements                      (N, Ky, Kx) = float32, (4096, 120, 120)
# 2026-06-11 14:46:54,035 -
# 2026-06-11 14:46:54,035 - ### Setting up calibration ###
# 2026-06-11 14:46:54,036 - meas_calibration mode = 'fitRBF', value = None
# 2026-06-11 14:46:54,036 - Using loaded raw averaged measurement (before crop/pad/resample) to fit RBF as a part of the meas calibration
# 2026-06-11 14:46:54,037 - Radius of fitted bright field disk (RBF) = 26.04 px with Npix = 256
# 2026-06-11 14:46:54,040 - Suggested probe_mask_k radius (RBF*2/Npix) > 0.2035
# 2026-06-11 14:46:54,041 - Fitting raw averaged measurement with center, radius, and Gaussian blur std as a sanity check
# 2026-06-11 14:46:54,041 - Note that the fitted Gaussian blur std (detector blur) would be affected by overlapping Bragg disks
# 2026-06-11 14:46:54,042 - Initial guess: center=(127.49, 127.84), radius=26.04, Gaussian blur std=0.50
# 2026-06-11 14:46:54,113 - Final fit: center=(127.49, 127.84), radius=26.04, Gaussian blur std=2.73
# 2026-06-11 14:46:54,113 - WARNING: The 'fitRBF' and 'RBF' calibration methods are highly dependent on the accuracy of user-provided experimental parameters and acquisition conditions,
# 2026-06-11 14:46:54,114 -          including convergence angle, kV, dose, specimen thickness, and collection angle for the estimation of RBF.
# 2026-06-11 14:46:54,114 -          For example, a 5-10% error in convergence angle is fairly common.
# 2026-06-11 14:46:54,115 -          Users are strongly advised to perform proper microscope calibration to ensure accurate results.
# 2026-06-11 14:46:54,115 -          These method should only be used as a rough estimate and not as a substitute for proper experimental calibration.
# 2026-06-11 14:46:54,116 - dx (real space pixel size of probe and object) set to 0.0936 Ang with Npix = 256
# 2026-06-11 14:46:54,116 - Update dx to 0.1997 Ang due to meas_crop, Npix = 120
# 2026-06-11 14:46:54,117 - Suggested probe_mask_k radius (RBF*2/Npix) changes to > 0.4341
# 2026-06-11 14:46:54,117 - Update dx to 0.0936 Ang due to meas_pad (mode = on_the_fly, padding_type = power), Npix = 256
# 2026-06-11 14:46:54,118 - Suggested probe_mask_k radius (RBF*2/Npix) changes to > 0.2035
# 2026-06-11 14:46:54,118 -
# 2026-06-11 14:46:54,118 - ### Setting init_variables dict ###
# 2026-06-11 14:46:54,119 - Derived values given input init_params:
# 2026-06-11 14:46:54,119 -   kv          = 300.0 kV
# 2026-06-11 14:46:54,120 -   wavelength  = 0.0197 Ang
# 2026-06-11 14:46:54,120 -   conv_angle  = 21.4 mrad
# 2026-06-11 14:46:54,120 -   Npix        = 256 px
# 2026-06-11 14:46:54,121 -   dk          = 0.0417 Ang^-1
# 2026-06-11 14:46:54,121 -   kMax        = 5.3422 Ang^-1
# 2026-06-11 14:46:54,122 -   da          = 0.8217 mrad
# 2026-06-11 14:46:54,122 -   angleMax    = 105.1737 mrad
# 2026-06-11 14:46:54,122 -   RBF         = 26.0445 px (Inferred from the given calibration, NOT necessarily from the loaded measurement data)
# 2026-06-11 14:46:54,123 -   n_alpha     = 4.9147 (# conv_angle)
# 2026-06-11 14:46:54,123 -   dx          = 0.0936 Ang, Nyquist-limited dmin = 2*dx = 0.1872 Ang
# 2026-06-11 14:46:54,123 -   Rayleigh-limited resolution  = 0.5612 Ang (0.61*lambda/alpha for focused probe )
# 2026-06-11 14:46:54,124 -   Real space probe extent = 23.9604 Ang
# 2026-06-11 14:46:54,124 -
# 2026-06-11 14:46:54,125 - ### Initializing probe ###
# 2026-06-11 14:46:54,125 - Loading probe from source = 'simu'
# 2026-06-11 14:46:54,125 - Using experimental parameters specified by 'init_params' for initial probe simulation.
# 2026-06-11 14:46:54,126 - Start simulating STEM probe
# 2026-06-11 14:46:54,137 -   kv          = 300.0 kV
# 2026-06-11 14:46:54,138 -   wavelength  = 0.0197 Ang
# 2026-06-11 14:46:54,138 -   conv_angle  = 21.4 mrad
# 2026-06-11 14:46:54,139 -   Npix        = 256 px
# 2026-06-11 14:46:54,139 -   dk          = 0.0417 Ang^-1
# 2026-06-11 14:46:54,140 -   kMax        = 5.3422 Ang^-1
# 2026-06-11 14:46:54,140 -   alpha_max   = 105.1700 mrad
# 2026-06-11 14:46:54,140 -   dx          = 0.0936 Ang, Nyquist-limited dmin = 2*dx = 0.1872 Ang
# 2026-06-11 14:46:54,141 -   Rayleigh-limited resolution  = 0.5612 Ang (0.61*lambda/alpha for focused probe )
# 2026-06-11 14:46:54,141 -   Real space probe extent = 23.9604 Ang
# 2026-06-11 14:46:54,142 - Start making mixed-state STEM probe with 4 incoherent probe modes
# 2026-06-11 14:46:54,173 - Relative power of probe modes = [0.94 0.02 0.02 0.02]
# 2026-06-11 14:46:54,174 - Loaded probe shape = (4, 256, 256), dtype = complex128
# 2026-06-11 14:46:54,175 - pmode_now: 4 and pmode_max: 4, leaving the pmode unchanged.
# 2026-06-11 14:46:54,178 - Orthogonalizing 4 pmodes
# 2026-06-11 14:46:54,184 - Sorting 4 pmodes by their intensities
# 2026-06-11 14:46:54,190 - sum(|probe_data|**2) = 2319.31, while meas.mean(0).sum() = 2319.31
# 2026-06-11 14:46:54,191 - probe                         (pmode, Ny, Nx) = complex64, (4, 256, 256)
# 2026-06-11 14:46:54,192 -
# 2026-06-11 14:46:54,192 - ### Initializing probe positions ###
# 2026-06-11 14:46:54,193 - Loading probe positions from source = 'simu'
# 2026-06-11 14:46:54,193 - Using experimental parameters specified by 'init_params' (dx, scan_step size, N_scan_slow, N_scan_fast) for initial position simulation.
# 2026-06-11 14:46:54,194 - Simulating probe positions with dx = 0.0936, scan_step_size = 0.4100, N_scan_fast = 64, N_scan_slow = 64
# 2026-06-11 14:46:54,197 - Applying Gaussian distributed random displacement with std = 0.15 px to scan positions
# 2026-06-11 14:46:54,198 - crop_pos                                (N,2) = int16, (4096, 2)
# 2026-06-11 14:46:54,199 - crop_pos 1st and last px coords (y,x)         = ([54, 54], [330, 330])
# 2026-06-11 14:46:54,200 - crop_pos extent (Ang)                         = [25.83226341 25.83226341]
# 2026-06-11 14:46:54,200 - probe_pos_shifts                        (N,2) = float32, (4096, 2)
# 2026-06-11 14:46:54,201 -
# 2026-06-11 14:46:54,201 - ### Initializing object ###
# 2026-06-11 14:46:54,202 - Loading object from source = 'simu'
# 2026-06-11 14:46:54,202 - Using experimental parameters specified by 'init_params' for initial object simulation.
# 2026-06-11 14:46:54,497 - omode_now: 1 and omode_max: 1, leaving the omode unchanged.
# 2026-06-11 14:46:54,509 - object                    (omode, Nz, Ny, Nx) = complex64, (1, 21, 639, 639)
# 2026-06-11 14:46:54,510 - object extent                 (Z, Y, X) (Ang) = [210.      59.8073  59.8073]
# 2026-06-11 14:46:54,510 -
# 2026-06-11 14:46:54,510 - ### Initializing omode_occu from 'uniform' ###
# 2026-06-11 14:46:54,511 - omode_occu                            (omode) = float32, (1,)
# 2026-06-11 14:46:54,511 -
# 2026-06-11 14:46:54,512 - ### Initializing H (Fresnel propagator) ###
# 2026-06-11 14:46:54,512 - Calculating H with probe_shape = [256. 256.] px, dx = 0.0936 Ang, slice_thickness = 10.0000 Ang, lambd = 0.0197 Ang
# 2026-06-11 14:46:54,516 - H                                    (Ky, Kx) = complex64, (256, 256)
# 2026-06-11 14:46:54,517 -
# 2026-06-11 14:46:54,517 - ### Initializing obj tilts from = 'simu' ###
# 2026-06-11 14:46:54,517 - Initialized obj_tilts with init_tilts = [[0.0, 0.0]] (theta_y, theta_x) mrad
# 2026-06-11 14:46:54,518 - obj_tilts                              (N, 2) = float32, (1, 2)
# 2026-06-11 14:46:54,518 -
# 2026-06-11 14:46:54,519 - ### Checking consistency between input params with the initialized variables ###
# 2026-06-11 14:46:54,519 - Npix, DP measurements, probe, and H shapes will be consistent as '256' during on-the-fly measurement padding
# 2026-06-11 14:46:54,519 - N_scans, len(meas), N_scan_slow*N_scan_fast, len(crop_pos), and len(probe_pos_shifts) are consistent as '4096'
# 2026-06-11 14:46:54,520 - obj.shape[0] is consistent with len(omode_occu) as '1'
# 2026-06-11 14:46:54,521 - obj.shape[1] is consistent with Nlayer as '21'
# 2026-06-11 14:46:54,522 - crop positions (yx_min=[54 54], yx_max=[586 586]) are well contained inside object canvas (Ny,Nx) = (639, 639).
# 2026-06-11 14:46:54,523 - obj_tilts is consistent with either 1 or N_scans
# 2026-06-11 14:46:54,523 - Pass the consistency check of initialized variables, initialization is done!
# 2026-06-11 14:46:54,523 -
# 2026-06-11 14:46:54,524 - ### Initializing loss function ###
# 2026-06-11 14:46:54,524 - Active loss types:
# 2026-06-11 14:46:54,524 -   loss_single : {'state': True, 'weight': 1.0, 'dp_pow': 0.5}
# 2026-06-11 14:46:54,525 -   loss_sparse : {'state': True, 'weight': 0.1, 'ln_order': 1}
# 2026-06-11 14:46:54,525 -
# 2026-06-11 14:46:54,526 - ### Initializing constraint function ###
# 2026-06-11 14:46:54,526 - Active constraint types:
# 2026-06-11 14:46:54,526 -   ortho_pmode   : {'start_iter': 1, 'step': 1, 'end_iter': None}
# 2026-06-11 14:46:54,527 -   fix_probe_int : {'start_iter': 1, 'step': 1, 'end_iter': None}
# 2026-06-11 14:46:54,527 -   obj_rblur     : {'start_iter': 1, 'step': 1, 'end_iter': None, 'obj_type': 'both', 'kernel_size': 5, 'std': 0.4}
# 2026-06-11 14:46:54,528 -   obj_zblur     : {'start_iter': 1, 'step': 1, 'end_iter': None, 'obj_type': 'both', 'kernel_size': 5, 'std': 1.0}
# 2026-06-11 14:46:54,528 -   mirrored_amp  : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.1, 'scale': 0.03, 'power': 4.0}
# 2026-06-11 14:46:54,528 -   obja_thresh   : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.0, 'thresh': [0.96, 1.04]}
# 2026-06-11 14:46:54,529 -   objp_postiv   : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.0}
# 2026-06-11 14:46:54,529 -
# 2026-06-11 14:46:54,530 - ### Done initializing PtyRADSolver ###
# 2026-06-11 14:46:54,530 -

# %%
ptycho_solver.run()

# Only `reconstruct` mode will return the final reconstructed model, because it's infeasible to store all models in `hypertune` mode and we don't know which model to return in `hypertune` mode
if not ptycho_solver.if_hypertune:
    model = ptycho_solver.reconstruct_results
# Out:
# 2026-06-11 14:46:54,602 - ### Starting the PtyRADSolver in reconstruct mode ###
# 2026-06-11 14:46:54,603 -
# 2026-06-11 14:46:54,604 - ### Initializing PtychoAD model ###
# 2026-06-11 14:46:54,757 - ### PtychoAD optimizable variables ###
# 2026-06-11 14:46:54,757 - obja            : torch.Size([1, 21, 639, 639])   , torch.float32   , device:cuda:0, grad:True , lr:1e-03
# 2026-06-11 14:46:54,758 - objp            : torch.Size([1, 21, 639, 639])   , torch.float32   , device:cuda:0, grad:True , lr:1e-03
# 2026-06-11 14:46:54,758 - obj_tilts       : torch.Size([1, 2])              , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-06-11 14:46:54,759 - slice_thickness : torch.Size([])                  , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-06-11 14:46:54,759 - probe           : torch.Size([4, 256, 256, 2])    , torch.float32   , device:cuda:0, grad:True , lr:1e-04
# 2026-06-11 14:46:54,760 - probe_pos_shifts: torch.Size([4096, 2])           , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-06-11 14:46:54,760 -
# 2026-06-11 14:46:54,760 - ### Optimizable variables statitsics ###
# 2026-06-11 14:46:54,761 - Total measurement values  : 58,982,400
# 2026-06-11 14:46:54,761 - Total optimizing variables: 17,673,770
# 2026-06-11 14:46:54,762 - Overdetermined ratio      : 3.34
# 2026-06-11 14:46:54,762 -
# 2026-06-11 14:46:54,762 - ### Model behavior ###
# 2026-06-11 14:46:54,763 - Obj preblur               : False
# 2026-06-11 14:46:54,763 - Tilt propagator           : False
# 2026-06-11 14:46:54,763 - Change slice thickness    : False
# 2026-06-11 14:46:54,764 - Sub-px probe shift        : False
# 2026-06-11 14:46:54,764 - Detector blur             : True
# 2026-06-11 14:46:54,764 - On-the-fly meas padding   : True
# 2026-06-11 14:46:54,765 - On-the-fly meas resample  : False
# 2026-06-11 14:46:54,765 - Solver type               : linduda
# 2026-06-11 14:46:54,766 - Linduda order             : 4
# 2026-06-11 14:46:54,766 -
# 2026-06-11 14:46:54,808 - ### Done initializing PtychoAD model ###
# 2026-06-11 14:46:54,808 -
# 2026-06-11 14:46:54,809 - ### Creating PyTorch 'Adam' optimizer with configs = {} ###
# 2026-06-11 14:46:54,810 -
# 2026-06-11 14:46:54,810 - ### Generating indices, batches, and output_path ###
# 2026-06-11 14:46:54,813 - d90 = 91.000 px or 8.517 Ang
# 2026-06-11 14:46:54,814 - Selecting indices with the 'full' mode
# 2026-06-11 14:47:09,384 - Generated 512 'sparse' groups of ~8 scan positions in 14.115 sec
# 2026-06-11 14:47:10,389 - The effective batch size (i.e., how many probe positions are simultaneously used for 1 update of ptychographic parameters) is batch_size * grad_accumulation = 8 * 1 = 8
# 2026-06-11 14:47:10,390 - Original recon_dir_affixes = ['default']
# 2026-06-11 14:47:10,391 - Expanded recon_dir_affixes = ['indices', 'meas', 'batch', 'pmode', 'omode', 'nlayer', 'lr', 'model', 'constraint', 'loss', 'affine', 'tilt']
# 2026-06-11 14:47:10,404 - output_path = '/home/dnz75396/ptyrad/demo/output/linduda/20260611_full_N4096_dp256_sparse8_p4_1obj_21slice_dz10_plr1e-4_oalr1e-3_oplr1e-3_dpblur1.0_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1' is generated!
# 2026-06-11 14:47:12,685 -
# 2026-06-11 14:47:12,686 - ### Successfully copy 'PSO_reconstruct.yml' to '/home/dnz75396/ptyrad/demo/output/linduda/20260611_full_N4096_dp256_sparse8_p4_1obj_21slice_dz10_plr1e-4_oalr1e-3_oplr1e-3_dpblur1.0_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1' ###
# 2026-06-11 14:47:12,687 -
# 2026-06-11 14:47:12,688 - ### Log file is flushed (created) as /home/dnz75396/ptyrad/demo/output/linduda/20260611_full_N4096_dp256_sparse8_p4_1obj_21slice_dz10_plr1e-4_oalr1e-3_oplr1e-3_dpblur1.0_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/20260611_144712_ptyrad_log.txt ###
# 2026-06-11 14:47:12,688 -
# 2026-06-11 14:47:12,689 - ### Start the PtyRAD iterative ptycho reconstruction ###
# 2026-06-11 14:47:12,690 -
# 2026-06-11 14:47:12,690 - Iter: 1, obja.requires_grad = True
# 2026-06-11 14:47:12,691 - Iter: 1, objp.requires_grad = True
# 2026-06-11 14:47:12,691 - Iter: 1, obj_tilts.requires_grad = False
# 2026-06-11 14:47:12,692 - Iter: 1, slice_thickness.requires_grad = False
# 2026-06-11 14:47:12,692 - Iter: 1, probe.requires_grad = True
# 2026-06-11 14:47:12,693 - Iter: 1, probe_pos_shifts.requires_grad = False
# 2026-06-11 14:47:12,693 - Setting up PyTorch compiler with {'fullgraph': False, 'dynamic': None, 'backend': 'inductor', 'mode': 'default', 'options': None, 'disable': True}
# 2026-06-11 14:48:17,293 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 64.595 sec
# 2026-06-11 14:50:40,897 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 14:51:29,549 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 14:52:18,510 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.480 sec
# 2026-06-11 14:53:07,063 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 14:53:56,218 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 14:53:56,317 - Apply ortho pmode constraint at iter 1, relative pmode power = [0.877 0.057 0.041 0.025], probe int sum = 2449.6787
# 2026-06-11 14:53:56,318 - Apply fix probe int constraint at iter 1, probe int sum = 2319.3130
# 2026-06-11 14:53:56,319 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 1
# 2026-06-11 14:53:56,320 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 1
# 2026-06-11 14:53:56,498 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 1
# 2026-06-11 14:53:56,500 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 1
# 2026-06-11 14:53:56,514 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 1. obja range becomes (0.985, 1.017)
# 2026-06-11 14:53:56,515 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 1
# 2026-06-11 14:53:56,517 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 1. Original min = -0.167. objp range becomes (0.000, 0.173)
# 2026-06-11 14:53:56,519 - Iter: 1, Total Loss: 0.4887, loss_single: 0.4862, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0025, loss_simlar: 0.0000, in 6 min 43.821 sec
# 2026-06-11 14:53:56,520 -
# 2026-06-11 14:53:56,520 - Iter: 2, obja.requires_grad = True
# 2026-06-11 14:53:56,521 - Iter: 2, objp.requires_grad = True
# 2026-06-11 14:53:56,521 - Iter: 2, obj_tilts.requires_grad = False
# 2026-06-11 14:53:56,522 - Iter: 2, slice_thickness.requires_grad = False
# 2026-06-11 14:53:56,522 - Iter: 2, probe.requires_grad = True
# 2026-06-11 14:53:56,523 - Iter: 2, probe_pos_shifts.requires_grad = False
# 2026-06-11 14:53:57,061 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 14:54:46,381 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 14:55:35,041 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 14:56:24,004 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 14:57:12,546 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 14:58:01,695 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 14:58:01,699 - Apply ortho pmode constraint at iter 2, relative pmode power = [0.822 0.077 0.06  0.041], probe int sum = 2467.7795
# 2026-06-11 14:58:01,700 - Apply fix probe int constraint at iter 2, probe int sum = 2319.3127
# 2026-06-11 14:58:01,701 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 2
# 2026-06-11 14:58:01,702 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 2
# 2026-06-11 14:58:01,704 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 2
# 2026-06-11 14:58:01,705 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 2
# 2026-06-11 14:58:01,708 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 2. obja range becomes (0.982, 1.013)
# 2026-06-11 14:58:01,709 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 2
# 2026-06-11 14:58:01,711 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 2. Original min = -0.108. objp range becomes (0.000, 0.294)
# 2026-06-11 14:58:01,712 - Iter: 2, Total Loss: 0.4049, loss_single: 0.4027, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0022, loss_simlar: 0.0000, in 4 min 5.188 sec
# 2026-06-11 14:58:01,716 -
# 2026-06-11 14:58:01,717 - Iter: 3, obja.requires_grad = True
# 2026-06-11 14:58:01,718 - Iter: 3, objp.requires_grad = True
# 2026-06-11 14:58:01,718 - Iter: 3, obj_tilts.requires_grad = False
# 2026-06-11 14:58:01,719 - Iter: 3, slice_thickness.requires_grad = False
# 2026-06-11 14:58:01,719 - Iter: 3, probe.requires_grad = True
# 2026-06-11 14:58:01,719 - Iter: 3, probe_pos_shifts.requires_grad = False
# 2026-06-11 14:58:02,258 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 14:58:51,575 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 14:59:40,236 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:00:29,198 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:01:17,738 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:02:06,879 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:02:06,883 - Apply ortho pmode constraint at iter 3, relative pmode power = [0.806 0.083 0.066 0.045], probe int sum = 2373.7463
# 2026-06-11 15:02:06,884 - Apply fix probe int constraint at iter 3, probe int sum = 2319.3127
# 2026-06-11 15:02:06,885 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 3
# 2026-06-11 15:02:06,887 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 3
# 2026-06-11 15:02:06,888 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 3
# 2026-06-11 15:02:06,890 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 3
# 2026-06-11 15:02:06,893 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 3. obja range becomes (0.982, 1.015)
# 2026-06-11 15:02:06,893 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 3
# 2026-06-11 15:02:06,895 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 3. Original min = -0.110. objp range becomes (0.000, 0.393)
# 2026-06-11 15:02:06,897 - Iter: 3, Total Loss: 0.3858, loss_single: 0.3831, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0027, loss_simlar: 0.0000, in 4 min 5.175 sec
# 2026-06-11 15:02:06,899 -
# 2026-06-11 15:02:06,900 - Iter: 4, obja.requires_grad = True
# 2026-06-11 15:02:06,901 - Iter: 4, objp.requires_grad = True
# 2026-06-11 15:02:06,901 - Iter: 4, obj_tilts.requires_grad = False
# 2026-06-11 15:02:06,902 - Iter: 4, slice_thickness.requires_grad = False
# 2026-06-11 15:02:06,902 - Iter: 4, probe.requires_grad = True
# 2026-06-11 15:02:06,902 - Iter: 4, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:02:07,441 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:02:56,757 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:03:45,426 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:04:34,382 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:05:22,969 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:06:12,127 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:06:12,131 - Apply ortho pmode constraint at iter 4, relative pmode power = [0.79  0.087 0.072 0.051], probe int sum = 2376.2400
# 2026-06-11 15:06:12,132 - Apply fix probe int constraint at iter 4, probe int sum = 2319.3130
# 2026-06-11 15:06:12,133 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 4
# 2026-06-11 15:06:12,134 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 4
# 2026-06-11 15:06:12,136 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 4
# 2026-06-11 15:06:12,138 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 4
# 2026-06-11 15:06:12,141 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 4. obja range becomes (0.982, 1.017)
# 2026-06-11 15:06:12,141 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 4
# 2026-06-11 15:06:12,143 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 4. Original min = -0.114. objp range becomes (0.000, 0.485)
# 2026-06-11 15:06:12,144 - Iter: 4, Total Loss: 0.3738, loss_single: 0.3706, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0032, loss_simlar: 0.0000, in 4 min 5.241 sec
# 2026-06-11 15:06:12,149 -
# 2026-06-11 15:06:12,150 - Iter: 5, obja.requires_grad = True
# 2026-06-11 15:06:12,151 - Iter: 5, objp.requires_grad = True
# 2026-06-11 15:06:12,151 - Iter: 5, obj_tilts.requires_grad = False
# 2026-06-11 15:06:12,152 - Iter: 5, slice_thickness.requires_grad = False
# 2026-06-11 15:06:12,153 - Iter: 5, probe.requires_grad = True
# 2026-06-11 15:06:12,153 - Iter: 5, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:06:12,692 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:07:02,016 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:07:50,683 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.542 sec
# 2026-06-11 15:08:39,663 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:09:28,208 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:10:17,358 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:10:17,362 - Apply ortho pmode constraint at iter 5, relative pmode power = [0.767 0.094 0.079 0.06 ], probe int sum = 2395.8328
# 2026-06-11 15:10:17,363 - Apply fix probe int constraint at iter 5, probe int sum = 2319.3130
# 2026-06-11 15:10:17,364 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 5
# 2026-06-11 15:10:17,365 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 5
# 2026-06-11 15:10:17,367 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 5
# 2026-06-11 15:10:17,368 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 5
# 2026-06-11 15:10:17,371 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 5. obja range becomes (0.982, 1.017)
# 2026-06-11 15:10:17,372 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 5
# 2026-06-11 15:10:17,374 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 5. Original min = -0.115. objp range becomes (0.000, 0.563)
# 2026-06-11 15:10:17,375 - Iter: 5, Total Loss: 0.3631, loss_single: 0.3594, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0037, loss_simlar: 0.0000, in 4 min 5.220 sec
# 2026-06-11 15:10:17,378 -
# 2026-06-11 15:10:17,379 - Iter: 6, obja.requires_grad = True
# 2026-06-11 15:10:17,379 - Iter: 6, objp.requires_grad = True
# 2026-06-11 15:10:17,380 - Iter: 6, obj_tilts.requires_grad = False
# 2026-06-11 15:10:17,380 - Iter: 6, slice_thickness.requires_grad = False
# 2026-06-11 15:10:17,381 - Iter: 6, probe.requires_grad = True
# 2026-06-11 15:10:17,381 - Iter: 6, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:10:17,920 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:11:07,238 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:11:55,905 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 15:12:44,903 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:13:33,457 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:14:22,627 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:14:22,632 - Apply ortho pmode constraint at iter 6, relative pmode power = [0.741 0.102 0.088 0.07 ], probe int sum = 2406.5676
# 2026-06-11 15:14:22,633 - Apply fix probe int constraint at iter 6, probe int sum = 2319.3130
# 2026-06-11 15:14:22,634 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 6
# 2026-06-11 15:14:22,635 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 6
# 2026-06-11 15:14:22,636 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 6
# 2026-06-11 15:14:22,638 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 6
# 2026-06-11 15:14:22,641 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 6. obja range becomes (0.982, 1.017)
# 2026-06-11 15:14:22,641 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 6
# 2026-06-11 15:14:22,643 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 6. Original min = -0.115. objp range becomes (0.000, 0.622)
# 2026-06-11 15:14:22,645 - Iter: 6, Total Loss: 0.3538, loss_single: 0.3497, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0042, loss_simlar: 0.0000, in 4 min 5.262 sec
# 2026-06-11 15:14:22,649 -
# 2026-06-11 15:14:22,650 - Iter: 7, obja.requires_grad = True
# 2026-06-11 15:14:22,650 - Iter: 7, objp.requires_grad = True
# 2026-06-11 15:14:22,651 - Iter: 7, obj_tilts.requires_grad = False
# 2026-06-11 15:14:22,651 - Iter: 7, slice_thickness.requires_grad = False
# 2026-06-11 15:14:22,652 - Iter: 7, probe.requires_grad = True
# 2026-06-11 15:14:22,652 - Iter: 7, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:14:23,192 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:15:12,572 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 15:16:01,308 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 15:16:50,297 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:17:38,855 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:18:28,021 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:18:28,025 - Apply ortho pmode constraint at iter 7, relative pmode power = [0.715 0.11  0.096 0.08 ], probe int sum = 2406.4888
# 2026-06-11 15:18:28,026 - Apply fix probe int constraint at iter 7, probe int sum = 2319.3130
# 2026-06-11 15:18:28,027 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 7
# 2026-06-11 15:18:28,028 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 7
# 2026-06-11 15:18:28,029 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 7
# 2026-06-11 15:18:28,031 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 7
# 2026-06-11 15:18:28,034 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 7. obja range becomes (0.982, 1.015)
# 2026-06-11 15:18:28,034 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 7
# 2026-06-11 15:18:28,036 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 7. Original min = -0.115. objp range becomes (0.000, 0.660)
# 2026-06-11 15:18:28,038 - Iter: 7, Total Loss: 0.3463, loss_single: 0.3417, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0046, loss_simlar: 0.0000, in 4 min 5.384 sec
# 2026-06-11 15:18:28,041 -
# 2026-06-11 15:18:28,042 - Iter: 8, obja.requires_grad = True
# 2026-06-11 15:18:28,042 - Iter: 8, objp.requires_grad = True
# 2026-06-11 15:18:28,043 - Iter: 8, obj_tilts.requires_grad = False
# 2026-06-11 15:18:28,043 - Iter: 8, slice_thickness.requires_grad = False
# 2026-06-11 15:18:28,044 - Iter: 8, probe.requires_grad = True
# 2026-06-11 15:18:28,044 - Iter: 8, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:18:28,583 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.537 sec
# 2026-06-11 15:19:17,896 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:20:06,578 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:20:55,538 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:21:44,079 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:22:33,238 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:22:33,242 - Apply ortho pmode constraint at iter 8, relative pmode power = [0.69  0.117 0.104 0.089], probe int sum = 2401.9771
# 2026-06-11 15:22:33,243 - Apply fix probe int constraint at iter 8, probe int sum = 2319.3130
# 2026-06-11 15:22:33,244 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 8
# 2026-06-11 15:22:33,245 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 8
# 2026-06-11 15:22:33,246 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 8
# 2026-06-11 15:22:33,248 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 8
# 2026-06-11 15:22:33,251 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 8. obja range becomes (0.981, 1.015)
# 2026-06-11 15:22:33,251 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 8
# 2026-06-11 15:22:33,253 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 8. Original min = -0.111. objp range becomes (0.000, 0.730)
# 2026-06-11 15:22:33,255 - Iter: 8, Total Loss: 0.3402, loss_single: 0.3353, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0049, loss_simlar: 0.0000, in 4 min 5.209 sec
# 2026-06-11 15:22:33,259 -
# 2026-06-11 15:22:33,260 - Iter: 9, obja.requires_grad = True
# 2026-06-11 15:22:33,260 - Iter: 9, objp.requires_grad = True
# 2026-06-11 15:22:33,261 - Iter: 9, obj_tilts.requires_grad = False
# 2026-06-11 15:22:33,261 - Iter: 9, slice_thickness.requires_grad = False
# 2026-06-11 15:22:33,262 - Iter: 9, probe.requires_grad = True
# 2026-06-11 15:22:33,262 - Iter: 9, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:22:33,801 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.537 sec
# 2026-06-11 15:23:23,119 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:24:11,784 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 15:25:00,741 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:25:49,286 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:26:38,430 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:26:38,434 - Apply ortho pmode constraint at iter 9, relative pmode power = [0.667 0.125 0.111 0.097], probe int sum = 2396.0083
# 2026-06-11 15:26:38,435 - Apply fix probe int constraint at iter 9, probe int sum = 2319.3127
# 2026-06-11 15:26:38,436 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 9
# 2026-06-11 15:26:38,437 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 9
# 2026-06-11 15:26:38,439 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 9
# 2026-06-11 15:26:38,441 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 9
# 2026-06-11 15:26:38,444 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 9. obja range becomes (0.980, 1.014)
# 2026-06-11 15:26:38,444 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 9
# 2026-06-11 15:26:38,446 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 9. Original min = -0.109. objp range becomes (0.000, 0.805)
# 2026-06-11 15:26:38,448 - Iter: 9, Total Loss: 0.3352, loss_single: 0.3299, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0053, loss_simlar: 0.0000, in 4 min 5.184 sec
# 2026-06-11 15:26:38,451 -
# 2026-06-11 15:26:38,451 - Iter: 10, obja.requires_grad = True
# 2026-06-11 15:26:38,452 - Iter: 10, objp.requires_grad = True
# 2026-06-11 15:26:38,452 - Iter: 10, obj_tilts.requires_grad = False
# 2026-06-11 15:26:38,453 - Iter: 10, slice_thickness.requires_grad = False
# 2026-06-11 15:26:38,453 - Iter: 10, probe.requires_grad = True
# 2026-06-11 15:26:38,453 - Iter: 10, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:26:38,993 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:27:28,302 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:28:16,978 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:29:05,953 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:29:54,487 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:30:43,623 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:30:43,627 - Apply ortho pmode constraint at iter 10, relative pmode power = [0.646 0.132 0.118 0.104], probe int sum = 2390.2026
# 2026-06-11 15:30:43,628 - Apply fix probe int constraint at iter 10, probe int sum = 2319.3127
# 2026-06-11 15:30:43,629 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 10
# 2026-06-11 15:30:43,630 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 10
# 2026-06-11 15:30:43,631 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 10
# 2026-06-11 15:30:43,633 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 10
# 2026-06-11 15:30:43,636 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 10. obja range becomes (0.977, 1.014)
# 2026-06-11 15:30:43,637 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 10
# 2026-06-11 15:30:43,639 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 10. Original min = -0.104. objp range becomes (0.000, 0.862)
# 2026-06-11 15:30:43,640 - Iter: 10, Total Loss: 0.3310, loss_single: 0.3254, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0056, loss_simlar: 0.0000, in 4 min 5.185 sec
# 2026-06-11 15:30:43,878 - Saving summary figures for iter 10
# 2026-06-11 15:31:25,582 -
# 2026-06-11 15:31:25,584 - Iter: 11, obja.requires_grad = True
# 2026-06-11 15:31:25,584 - Iter: 11, objp.requires_grad = True
# 2026-06-11 15:31:25,585 - Iter: 11, obj_tilts.requires_grad = False
# 2026-06-11 15:31:25,585 - Iter: 11, slice_thickness.requires_grad = False
# 2026-06-11 15:31:25,586 - Iter: 11, probe.requires_grad = True
# 2026-06-11 15:31:25,586 - Iter: 11, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:31:26,125 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:32:15,407 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 15:33:04,070 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:33:53,033 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:34:41,570 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:35:30,724 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:35:30,728 - Apply ortho pmode constraint at iter 11, relative pmode power = [0.627 0.138 0.125 0.11 ], probe int sum = 2383.9670
# 2026-06-11 15:35:30,729 - Apply fix probe int constraint at iter 11, probe int sum = 2319.3130
# 2026-06-11 15:35:30,731 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 11
# 2026-06-11 15:35:30,732 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 11
# 2026-06-11 15:35:30,733 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 11
# 2026-06-11 15:35:30,735 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 11
# 2026-06-11 15:35:30,738 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 11. obja range becomes (0.975, 1.014)
# 2026-06-11 15:35:30,739 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 11
# 2026-06-11 15:35:30,741 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 11. Original min = -0.105. objp range becomes (0.000, 0.903)
# 2026-06-11 15:35:30,742 - Iter: 11, Total Loss: 0.3275, loss_single: 0.3216, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0059, loss_simlar: 0.0000, in 4 min 5.155 sec
# 2026-06-11 15:35:30,745 -
# 2026-06-11 15:35:30,746 - Iter: 12, obja.requires_grad = True
# 2026-06-11 15:35:30,747 - Iter: 12, objp.requires_grad = True
# 2026-06-11 15:35:30,747 - Iter: 12, obj_tilts.requires_grad = False
# 2026-06-11 15:35:30,748 - Iter: 12, slice_thickness.requires_grad = False
# 2026-06-11 15:35:30,748 - Iter: 12, probe.requires_grad = True
# 2026-06-11 15:35:30,749 - Iter: 12, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:35:31,287 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:36:20,610 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:37:09,281 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:37:58,258 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:38:46,804 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:39:35,970 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:39:35,974 - Apply ortho pmode constraint at iter 12, relative pmode power = [0.61  0.144 0.131 0.115], probe int sum = 2378.2578
# 2026-06-11 15:39:35,975 - Apply fix probe int constraint at iter 12, probe int sum = 2319.3130
# 2026-06-11 15:39:35,976 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 12
# 2026-06-11 15:39:35,978 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 12
# 2026-06-11 15:39:35,979 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 12
# 2026-06-11 15:39:35,981 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 12
# 2026-06-11 15:39:35,984 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 12. obja range becomes (0.972, 1.015)
# 2026-06-11 15:39:35,985 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 12
# 2026-06-11 15:39:35,986 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 12. Original min = -0.102. objp range becomes (0.000, 0.931)
# 2026-06-11 15:39:35,988 - Iter: 12, Total Loss: 0.3244, loss_single: 0.3182, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0062, loss_simlar: 0.0000, in 4 min 5.238 sec
# 2026-06-11 15:39:35,992 -
# 2026-06-11 15:39:35,993 - Iter: 13, obja.requires_grad = True
# 2026-06-11 15:39:35,993 - Iter: 13, objp.requires_grad = True
# 2026-06-11 15:39:35,994 - Iter: 13, obj_tilts.requires_grad = False
# 2026-06-11 15:39:35,994 - Iter: 13, slice_thickness.requires_grad = False
# 2026-06-11 15:39:35,995 - Iter: 13, probe.requires_grad = True
# 2026-06-11 15:39:35,995 - Iter: 13, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:39:36,534 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:40:25,849 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:41:14,508 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:42:03,498 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:42:52,048 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:43:41,189 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:43:41,193 - Apply ortho pmode constraint at iter 13, relative pmode power = [0.595 0.149 0.136 0.12 ], probe int sum = 2372.8838
# 2026-06-11 15:43:41,194 - Apply fix probe int constraint at iter 13, probe int sum = 2319.3127
# 2026-06-11 15:43:41,195 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 13
# 2026-06-11 15:43:41,196 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 13
# 2026-06-11 15:43:41,197 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 13
# 2026-06-11 15:43:41,199 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 13
# 2026-06-11 15:43:41,202 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 13. obja range becomes (0.968, 1.015)
# 2026-06-11 15:43:41,202 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 13
# 2026-06-11 15:43:41,204 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 13. Original min = -0.103. objp range becomes (0.000, 0.950)
# 2026-06-11 15:43:41,206 - Iter: 13, Total Loss: 0.3218, loss_single: 0.3153, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0064, loss_simlar: 0.0000, in 4 min 5.209 sec
# 2026-06-11 15:43:41,209 -
# 2026-06-11 15:43:41,210 - Iter: 14, obja.requires_grad = True
# 2026-06-11 15:43:41,210 - Iter: 14, objp.requires_grad = True
# 2026-06-11 15:43:41,211 - Iter: 14, obj_tilts.requires_grad = False
# 2026-06-11 15:43:41,211 - Iter: 14, slice_thickness.requires_grad = False
# 2026-06-11 15:43:41,211 - Iter: 14, probe.requires_grad = True
# 2026-06-11 15:43:41,212 - Iter: 14, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:43:41,751 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.537 sec
# 2026-06-11 15:44:31,086 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 15:45:19,770 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 15:46:08,740 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:46:57,291 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:47:46,444 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:47:46,449 - Apply ortho pmode constraint at iter 14, relative pmode power = [0.582 0.154 0.141 0.124], probe int sum = 2367.7520
# 2026-06-11 15:47:46,450 - Apply fix probe int constraint at iter 14, probe int sum = 2319.3132
# 2026-06-11 15:47:46,451 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 14
# 2026-06-11 15:47:46,452 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 14
# 2026-06-11 15:47:46,453 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 14
# 2026-06-11 15:47:46,455 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 14
# 2026-06-11 15:47:46,458 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 14. obja range becomes (0.964, 1.015)
# 2026-06-11 15:47:46,458 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 14
# 2026-06-11 15:47:46,460 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 14. Original min = -0.103. objp range becomes (0.000, 0.962)
# 2026-06-11 15:47:46,462 - Iter: 14, Total Loss: 0.3194, loss_single: 0.3127, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0067, loss_simlar: 0.0000, in 4 min 5.248 sec
# 2026-06-11 15:47:46,466 -
# 2026-06-11 15:47:46,467 - Iter: 15, obja.requires_grad = True
# 2026-06-11 15:47:46,468 - Iter: 15, objp.requires_grad = True
# 2026-06-11 15:47:46,468 - Iter: 15, obj_tilts.requires_grad = False
# 2026-06-11 15:47:46,469 - Iter: 15, slice_thickness.requires_grad = False
# 2026-06-11 15:47:46,469 - Iter: 15, probe.requires_grad = True
# 2026-06-11 15:47:46,470 - Iter: 15, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:47:47,008 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:48:36,329 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 15:49:24,997 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:50:13,964 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:51:02,525 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:51:51,673 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:51:51,678 - Apply ortho pmode constraint at iter 15, relative pmode power = [0.571 0.158 0.145 0.127], probe int sum = 2363.4141
# 2026-06-11 15:51:51,679 - Apply fix probe int constraint at iter 15, probe int sum = 2319.3130
# 2026-06-11 15:51:51,680 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 15
# 2026-06-11 15:51:51,681 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 15
# 2026-06-11 15:51:51,682 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 15
# 2026-06-11 15:51:51,684 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 15
# 2026-06-11 15:51:51,687 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 15. obja range becomes (0.961, 1.015)
# 2026-06-11 15:51:51,688 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 15
# 2026-06-11 15:51:51,689 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 15. Original min = -0.102. objp range becomes (0.000, 0.990)
# 2026-06-11 15:51:51,691 - Iter: 15, Total Loss: 0.3173, loss_single: 0.3104, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0069, loss_simlar: 0.0000, in 4 min 5.220 sec
# 2026-06-11 15:51:51,695 -
# 2026-06-11 15:51:51,696 - Iter: 16, obja.requires_grad = True
# 2026-06-11 15:51:51,696 - Iter: 16, objp.requires_grad = True
# 2026-06-11 15:51:51,697 - Iter: 16, obj_tilts.requires_grad = False
# 2026-06-11 15:51:51,697 - Iter: 16, slice_thickness.requires_grad = False
# 2026-06-11 15:51:51,698 - Iter: 16, probe.requires_grad = True
# 2026-06-11 15:51:51,699 - Iter: 16, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:51:52,238 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:52:41,561 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 15:53:30,231 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 15:54:19,197 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:55:07,766 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 15:55:56,932 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 15:55:56,937 - Apply ortho pmode constraint at iter 16, relative pmode power = [0.561 0.161 0.148 0.13 ], probe int sum = 2359.4534
# 2026-06-11 15:55:56,938 - Apply fix probe int constraint at iter 16, probe int sum = 2319.3130
# 2026-06-11 15:55:56,939 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 16
# 2026-06-11 15:55:56,940 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 16
# 2026-06-11 15:55:56,941 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 16
# 2026-06-11 15:55:56,943 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 16
# 2026-06-11 15:55:56,946 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 16. obja range becomes (0.959, 1.014)
# 2026-06-11 15:55:56,946 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 16
# 2026-06-11 15:55:56,948 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 16. Original min = -0.103. objp range becomes (0.000, 1.008)
# 2026-06-11 15:55:56,950 - Iter: 16, Total Loss: 0.3153, loss_single: 0.3083, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0071, loss_simlar: 0.0000, in 4 min 5.249 sec
# 2026-06-11 15:55:56,954 -
# 2026-06-11 15:55:56,955 - Iter: 17, obja.requires_grad = True
# 2026-06-11 15:55:56,955 - Iter: 17, objp.requires_grad = True
# 2026-06-11 15:55:56,956 - Iter: 17, obj_tilts.requires_grad = False
# 2026-06-11 15:55:56,956 - Iter: 17, slice_thickness.requires_grad = False
# 2026-06-11 15:55:56,957 - Iter: 17, probe.requires_grad = True
# 2026-06-11 15:55:56,957 - Iter: 17, probe_pos_shifts.requires_grad = False
# 2026-06-11 15:55:57,496 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 15:56:46,841 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 15:57:35,514 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 15:58:24,487 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 15:59:13,047 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:00:02,209 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:00:02,214 - Apply ortho pmode constraint at iter 17, relative pmode power = [0.553 0.164 0.152 0.132], probe int sum = 2356.1299
# 2026-06-11 16:00:02,215 - Apply fix probe int constraint at iter 17, probe int sum = 2319.3130
# 2026-06-11 16:00:02,216 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 17
# 2026-06-11 16:00:02,217 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 17
# 2026-06-11 16:00:02,218 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 17
# 2026-06-11 16:00:02,220 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 17
# 2026-06-11 16:00:02,223 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 17. obja range becomes (0.957, 1.014)
# 2026-06-11 16:00:02,224 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 17
# 2026-06-11 16:00:02,225 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 17. Original min = -0.105. objp range becomes (0.000, 1.016)
# 2026-06-11 16:00:02,227 - Iter: 17, Total Loss: 0.3136, loss_single: 0.3063, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0072, loss_simlar: 0.0000, in 4 min 5.268 sec
# 2026-06-11 16:00:02,231 -
# 2026-06-11 16:00:02,232 - Iter: 18, obja.requires_grad = True
# 2026-06-11 16:00:02,232 - Iter: 18, objp.requires_grad = True
# 2026-06-11 16:00:02,232 - Iter: 18, obj_tilts.requires_grad = False
# 2026-06-11 16:00:02,233 - Iter: 18, slice_thickness.requires_grad = False
# 2026-06-11 16:00:02,234 - Iter: 18, probe.requires_grad = True
# 2026-06-11 16:00:02,235 - Iter: 18, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:00:02,774 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:00:52,088 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 16:01:40,752 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 16:02:29,714 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:03:18,252 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:04:07,397 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:04:07,401 - Apply ortho pmode constraint at iter 18, relative pmode power = [0.546 0.166 0.154 0.134], probe int sum = 2353.0281
# 2026-06-11 16:04:07,402 - Apply fix probe int constraint at iter 18, probe int sum = 2319.3127
# 2026-06-11 16:04:07,404 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 18
# 2026-06-11 16:04:07,405 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 18
# 2026-06-11 16:04:07,406 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 18
# 2026-06-11 16:04:07,408 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 18
# 2026-06-11 16:04:07,411 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 18. obja range becomes (0.956, 1.013)
# 2026-06-11 16:04:07,411 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 18
# 2026-06-11 16:04:07,413 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 18. Original min = -0.105. objp range becomes (0.000, 1.021)
# 2026-06-11 16:04:07,415 - Iter: 18, Total Loss: 0.3119, loss_single: 0.3045, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0074, loss_simlar: 0.0000, in 4 min 5.178 sec
# 2026-06-11 16:04:07,419 -
# 2026-06-11 16:04:07,420 - Iter: 19, obja.requires_grad = True
# 2026-06-11 16:04:07,420 - Iter: 19, objp.requires_grad = True
# 2026-06-11 16:04:07,421 - Iter: 19, obj_tilts.requires_grad = False
# 2026-06-11 16:04:07,421 - Iter: 19, slice_thickness.requires_grad = False
# 2026-06-11 16:04:07,422 - Iter: 19, probe.requires_grad = True
# 2026-06-11 16:04:07,422 - Iter: 19, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:04:07,961 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:04:57,275 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 16:05:45,948 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 16:06:34,951 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:07:23,496 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:08:12,657 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:08:12,661 - Apply ortho pmode constraint at iter 19, relative pmode power = [0.54  0.168 0.156 0.135], probe int sum = 2350.3892
# 2026-06-11 16:08:12,662 - Apply fix probe int constraint at iter 19, probe int sum = 2319.3127
# 2026-06-11 16:08:12,663 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 19
# 2026-06-11 16:08:12,664 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 19
# 2026-06-11 16:08:12,666 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 19
# 2026-06-11 16:08:12,667 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 19
# 2026-06-11 16:08:12,670 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 19. obja range becomes (0.953, 1.013)
# 2026-06-11 16:08:12,671 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 19
# 2026-06-11 16:08:12,673 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 19. Original min = -0.105. objp range becomes (0.000, 1.046)
# 2026-06-11 16:08:12,675 - Iter: 19, Total Loss: 0.3104, loss_single: 0.3028, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0075, loss_simlar: 0.0000, in 4 min 5.250 sec
# 2026-06-11 16:08:12,678 -
# 2026-06-11 16:08:12,679 - Iter: 20, obja.requires_grad = True
# 2026-06-11 16:08:12,680 - Iter: 20, objp.requires_grad = True
# 2026-06-11 16:08:12,680 - Iter: 20, obj_tilts.requires_grad = False
# 2026-06-11 16:08:12,681 - Iter: 20, slice_thickness.requires_grad = False
# 2026-06-11 16:08:12,681 - Iter: 20, probe.requires_grad = True
# 2026-06-11 16:08:12,682 - Iter: 20, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:08:13,220 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# ...
# 2026-06-11 16:14:48,349 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:15:36,899 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:16:26,039 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:16:26,043 - Apply ortho pmode constraint at iter 21, relative pmode power = [0.532 0.171 0.16  0.137], probe int sum = 2346.4060
# 2026-06-11 16:16:26,044 - Apply fix probe int constraint at iter 21, probe int sum = 2319.3125
# 2026-06-11 16:16:26,045 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 21
# 2026-06-11 16:16:26,046 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 21
# 2026-06-11 16:16:26,048 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 21
# 2026-06-11 16:16:26,049 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 21
# 2026-06-11 16:16:26,052 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 21. obja range becomes (0.947, 1.013)
# 2026-06-11 16:16:26,053 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 21
# 2026-06-11 16:16:26,055 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 21. Original min = -0.105. objp range becomes (0.000, 1.088)
# 2026-06-11 16:16:26,056 - Iter: 21, Total Loss: 0.3076, loss_single: 0.2998, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0077, loss_simlar: 0.0000, in 4 min 5.324 sec
# 2026-06-11 16:16:26,061 -
# 2026-06-11 16:16:26,061 - Iter: 22, obja.requires_grad = True
# 2026-06-11 16:16:26,062 - Iter: 22, objp.requires_grad = True
# 2026-06-11 16:16:26,062 - Iter: 22, obj_tilts.requires_grad = False
# 2026-06-11 16:16:26,063 - Iter: 22, slice_thickness.requires_grad = False
# 2026-06-11 16:16:26,063 - Iter: 22, probe.requires_grad = True
# 2026-06-11 16:16:26,064 - Iter: 22, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:16:26,603 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:17:15,911 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 16:18:04,588 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 16:18:53,563 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:19:42,127 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:20:31,334 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:20:31,338 - Apply ortho pmode constraint at iter 22, relative pmode power = [0.528 0.172 0.161 0.138], probe int sum = 2345.1943
# 2026-06-11 16:20:31,339 - Apply fix probe int constraint at iter 22, probe int sum = 2319.3125
# 2026-06-11 16:20:31,341 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 22
# 2026-06-11 16:20:31,342 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 22
# 2026-06-11 16:20:31,343 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 22
# 2026-06-11 16:20:31,345 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 22
# 2026-06-11 16:20:31,348 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 22. obja range becomes (0.946, 1.013)
# 2026-06-11 16:20:31,349 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 22
# 2026-06-11 16:20:31,350 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 22. Original min = -0.103. objp range becomes (0.000, 1.098)
# 2026-06-11 16:20:31,352 - Iter: 22, Total Loss: 0.3063, loss_single: 0.2985, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0078, loss_simlar: 0.0000, in 4 min 5.287 sec
# 2026-06-11 16:20:31,355 -
# 2026-06-11 16:20:31,355 - Iter: 23, obja.requires_grad = True
# 2026-06-11 16:20:31,356 - Iter: 23, objp.requires_grad = True
# 2026-06-11 16:20:31,356 - Iter: 23, obj_tilts.requires_grad = False
# 2026-06-11 16:20:31,357 - Iter: 23, slice_thickness.requires_grad = False
# 2026-06-11 16:20:31,358 - Iter: 23, probe.requires_grad = True
# 2026-06-11 16:20:31,358 - Iter: 23, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:20:31,898 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:21:21,282 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 16:22:09,961 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 16:22:58,929 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:23:47,470 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:24:36,617 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:24:36,621 - Apply ortho pmode constraint at iter 23, relative pmode power = [0.526 0.173 0.162 0.139], probe int sum = 2344.0195
# 2026-06-11 16:24:36,622 - Apply fix probe int constraint at iter 23, probe int sum = 2319.3130
# 2026-06-11 16:24:36,623 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 23
# 2026-06-11 16:24:36,624 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 23
# 2026-06-11 16:24:36,626 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 23
# 2026-06-11 16:24:36,627 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 23
# 2026-06-11 16:24:36,630 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 23. obja range becomes (0.946, 1.012)
# 2026-06-11 16:24:36,631 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 23
# 2026-06-11 16:24:36,633 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 23. Original min = -0.100. objp range becomes (0.000, 1.103)
# 2026-06-11 16:24:36,634 - Iter: 23, Total Loss: 0.3051, loss_single: 0.2972, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0079, loss_simlar: 0.0000, in 4 min 5.275 sec
# 2026-06-11 16:24:36,639 -
# 2026-06-11 16:24:36,639 - Iter: 24, obja.requires_grad = True
# 2026-06-11 16:24:36,640 - Iter: 24, objp.requires_grad = True
# 2026-06-11 16:24:36,640 - Iter: 24, obj_tilts.requires_grad = False
# 2026-06-11 16:24:36,641 - Iter: 24, slice_thickness.requires_grad = False
# 2026-06-11 16:24:36,641 - Iter: 24, probe.requires_grad = True
# 2026-06-11 16:24:36,641 - Iter: 24, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:24:37,180 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.537 sec
# 2026-06-11 16:25:26,500 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 16:26:15,172 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 16:27:04,149 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:27:52,698 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:28:41,852 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:28:41,856 - Apply ortho pmode constraint at iter 24, relative pmode power = [0.524 0.174 0.163 0.139], probe int sum = 2342.9238
# 2026-06-11 16:28:41,857 - Apply fix probe int constraint at iter 24, probe int sum = 2319.3130
# 2026-06-11 16:28:41,858 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 24
# 2026-06-11 16:28:41,859 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 24
# 2026-06-11 16:28:41,861 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 24
# 2026-06-11 16:28:41,862 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 24
# 2026-06-11 16:28:41,865 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 24. obja range becomes (0.946, 1.012)
# 2026-06-11 16:28:41,866 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 24
# 2026-06-11 16:28:41,868 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 24. Original min = -0.096. objp range becomes (0.000, 1.107)
# 2026-06-11 16:28:41,870 - Iter: 24, Total Loss: 0.3040, loss_single: 0.2961, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0079, loss_simlar: 0.0000, in 4 min 5.226 sec
# 2026-06-11 16:28:41,873 -
# 2026-06-11 16:28:41,873 - Iter: 25, obja.requires_grad = True
# 2026-06-11 16:28:41,874 - Iter: 25, objp.requires_grad = True
# 2026-06-11 16:28:41,874 - Iter: 25, obj_tilts.requires_grad = False
# 2026-06-11 16:28:41,875 - Iter: 25, slice_thickness.requires_grad = False
# 2026-06-11 16:28:41,875 - Iter: 25, probe.requires_grad = True
# 2026-06-11 16:28:41,876 - Iter: 25, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:28:42,415 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:29:31,763 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 16:30:20,438 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 16:31:09,411 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:31:57,977 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:32:47,127 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:32:47,131 - Apply ortho pmode constraint at iter 25, relative pmode power = [0.522 0.175 0.163 0.14 ], probe int sum = 2342.7300
# 2026-06-11 16:32:47,132 - Apply fix probe int constraint at iter 25, probe int sum = 2319.3130
# 2026-06-11 16:32:47,133 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 25
# 2026-06-11 16:32:47,134 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 25
# 2026-06-11 16:32:47,136 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 25
# 2026-06-11 16:32:47,137 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 25
# 2026-06-11 16:32:47,140 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 25. obja range becomes (0.944, 1.013)
# 2026-06-11 16:32:47,141 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 25
# 2026-06-11 16:32:47,143 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 25. Original min = -0.095. objp range becomes (0.000, 1.118)
# 2026-06-11 16:32:47,144 - Iter: 25, Total Loss: 0.3029, loss_single: 0.2949, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0080, loss_simlar: 0.0000, in 4 min 5.267 sec
# 2026-06-11 16:32:47,148 -
# 2026-06-11 16:32:47,149 - Iter: 26, obja.requires_grad = True
# 2026-06-11 16:32:47,150 - Iter: 26, objp.requires_grad = True
# 2026-06-11 16:32:47,150 - Iter: 26, obj_tilts.requires_grad = False
# 2026-06-11 16:32:47,151 - Iter: 26, slice_thickness.requires_grad = False
# 2026-06-11 16:32:47,151 - Iter: 26, probe.requires_grad = True
# 2026-06-11 16:32:47,152 - Iter: 26, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:32:47,690 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:33:37,005 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
# 2026-06-11 16:34:25,668 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.537 sec
# 2026-06-11 16:35:14,636 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:36:03,192 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:36:52,338 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:36:52,342 - Apply ortho pmode constraint at iter 26, relative pmode power = [0.52  0.176 0.164 0.14 ], probe int sum = 2341.7822
# 2026-06-11 16:36:52,343 - Apply fix probe int constraint at iter 26, probe int sum = 2319.3125
# 2026-06-11 16:36:52,344 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 26
# 2026-06-11 16:36:52,345 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 26
# 2026-06-11 16:36:52,347 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 26
# 2026-06-11 16:36:52,349 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 26
# 2026-06-11 16:36:52,352 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 26. obja range becomes (0.940, 1.013)
# 2026-06-11 16:36:52,352 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 26
# 2026-06-11 16:36:52,354 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 26. Original min = -0.093. objp range becomes (0.000, 1.140)
# 2026-06-11 16:36:52,356 - Iter: 26, Total Loss: 0.3019, loss_single: 0.2939, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0080, loss_simlar: 0.0000, in 4 min 5.202 sec
# 2026-06-11 16:36:52,359 -
# 2026-06-11 16:36:52,360 - Iter: 27, obja.requires_grad = True
# 2026-06-11 16:36:52,360 - Iter: 27, objp.requires_grad = True
# 2026-06-11 16:36:52,361 - Iter: 27, obj_tilts.requires_grad = False
# 2026-06-11 16:36:52,361 - Iter: 27, slice_thickness.requires_grad = False
# 2026-06-11 16:36:52,362 - Iter: 27, probe.requires_grad = True
# 2026-06-11 16:36:52,362 - Iter: 27, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:36:52,901 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.537 sec
# 2026-06-11 16:37:42,223 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.538 sec
# 2026-06-11 16:38:30,905 - Done batch 205 with 9 indices ([3772, 6, 366, 918, 1705]...) in 0.538 sec
# 2026-06-11 16:39:19,877 - Done batch 307 with 8 indices ([3061, 145, 624, 1372, 1984]...) in 0.479 sec
# 2026-06-11 16:40:08,480 - Done batch 409 with 8 indices ([2062, 355, 1211, 1828, 2744]...) in 0.479 sec
# 2026-06-11 16:40:57,671 - Done batch 512 with 8 indices ([436, 518, 925, 1838, 1933]...) in 0.479 sec
# 2026-06-11 16:40:57,675 - Apply ortho pmode constraint at iter 27, relative pmode power = [0.519 0.177 0.164 0.14 ], probe int sum = 2340.9526
# 2026-06-11 16:40:57,676 - Apply fix probe int constraint at iter 27, probe int sum = 2319.3130
# 2026-06-11 16:40:57,677 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 27
# 2026-06-11 16:40:57,678 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 27
# 2026-06-11 16:40:57,680 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 27
# 2026-06-11 16:40:57,681 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 27
# 2026-06-11 16:40:57,684 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 27. obja range becomes (0.936, 1.013)
# 2026-06-11 16:40:57,685 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 27
# 2026-06-11 16:40:57,687 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 27. Original min = -0.090. objp range becomes (0.000, 1.166)
# 2026-06-11 16:40:57,689 - Iter: 27, Total Loss: 0.3009, loss_single: 0.2928, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0081, loss_simlar: 0.0000, in 4 min 5.324 sec
# 2026-06-11 16:40:57,693 -
# 2026-06-11 16:40:57,694 - Iter: 28, obja.requires_grad = True
# 2026-06-11 16:40:57,694 - Iter: 28, objp.requires_grad = True
# 2026-06-11 16:40:57,695 - Iter: 28, obj_tilts.requires_grad = False
# 2026-06-11 16:40:57,695 - Iter: 28, slice_thickness.requires_grad = False
# 2026-06-11 16:40:57,696 - Iter: 28, probe.requires_grad = True
# 2026-06-11 16:40:57,696 - Iter: 28, probe_pos_shifts.requires_grad = False
# 2026-06-11 16:40:58,235 - Done batch 1 with 9 indices ([4084, 8, 376, 862, 1482]...) in 0.538 sec
# 2026-06-11 16:41:47,548 - Done batch 103 with 9 indices ([3699, 68, 308, 794, 1580]...) in 0.537 sec
