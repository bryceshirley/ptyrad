# %% [markdown]
# # Quick example for PtyRAD
#
# - Created with PtyRAD 0.1.0b8
# - Requires PtyRAD >= 0.1.0b8
# - Latest demo params files / scripts: https://github.com/chiahao3/ptyrad/tree/main/demo
# - Documentation: https://ptyrad.readthedocs.io/en/latest/
# - PtyRAD paper: https://doi.org/10.1093/mam/ozaf070
# - PtyRAD arXiv: https://arxiv.org/abs/2505.07814
# - Zenodo record: https://doi.org/10.5281/zenodo.15273176
# - Box folder: https://cornell.box.com/s/n5balzf88jixescp9l15ojx7di4xn1uo
# - Youtube channel: https://www.youtube.com/@ptyrad_official
#
# **Before running this notebook, you must first follow the instruction in `README.md` to:**
# 1. Create the Python environment with all dependant Python packages like PyTorch
# 2. Activate that python environment
# 3. Install `ptyrad` package into your activated Python environement (only need to install once)
# 4. Download the demo data into `demo/data/` from the `demo/data/data_url.txt`
#
# > Note: This notebook is designed for "ease of operation with the solver class `PtyRADSolver`", both "reconstruction" and "hypertune" modes are supported.
#
# Author: Chia-Hao Lee, cl2696@cornell.edu

# %%
import os

# Change this to the ABSOLUTE PATH to the demo/ folder so you can correctly access data/ and params/
work_dir = "../"  # Leave this as-is if you're running the notebook from the `ptyrad/demo/scripts/` folder, this will change it back to demo/

os.chdir(work_dir)
print("Current working dir: ", os.getcwd())
# The printed working dir should be ".../ptyrad/demo" to locate the demo params files easily
# Note that the output/ directory will be automatically generated under your working directory
# Out:
# Current working dir:  /home/dnz75396/ptyrad/demo

# %%
from ptyrad.load import load_params
from ptyrad.reconstruction import PtyRADSolver
from ptyrad.utils import CustomLogger, print_system_info, set_gpu_device

logger = CustomLogger(
    log_file="ptyrad_log.txt", log_dir="auto", prefix_time="datetime", show_timestamp=True
)

# All the following params files are provided in demo/params/ and we're using relative path here
# So if you change the working directory, or have moved params files around, you'll have to provide absolute path to the params file

params_path = "params/tBL_WSe2_reconstruct_born.yml"
# params_path = "params/tBL_WSe2_reconstruct.yml"
# params_path = "params/PSO_reconstruct.yml"
# params_path = (
#     "params/tBL_WSe2_tuned.yml"  # This will run PtyRAD with the hyperparameter tuning mode
# )

print_system_info()

# We enable validation to auto-fill defaults and check parameter consistency since PtyRAD 0.1.0b8
# If you run into issues with validation (e.g., false positives or unexpected errors),
# you can temporarily disable it by setting `validate=False` and prepare a fully complete params file yourself.
# If this happens, please report the bug so we can improve the validation logic.
params = load_params(params_path, validate=True)

print("Loaded params: ", params)
device = set_gpu_device(
    gpuid=0
)  # Pass in `gpuid = None` if you don't have access to a CUDA-compatible GPU. Note that running PtyRAD with CPU would be much slower than on GPU.

ptycho_solver = PtyRADSolver(params, device=device, logger=logger)
# Out:
# 2026-07-23 18:37:19,239 - ### PtyRAD Logger configuration ###
# 2026-07-23 18:37:19,240 - log_file       = 'ptyrad_log.txt'. If log_file = None, no log file will be created.
# 2026-07-23 18:37:19,241 - log_dir        = 'auto'. If log_dir = 'auto', then log will be saved to `output_path` or 'logs/'.
# 2026-07-23 18:37:19,241 - flush_file     = True. Automatically set to True if `log_file is not None`
# 2026-07-23 18:37:19,241 - prefix_time    = datetime. If true, preset strings ('date', 'time', 'datetime'), or a string of time format, a datetime str is prefixed to the `log_file`.
# 2026-07-23 18:37:19,242 - prefix_jobid   = '0'. If not 0, it'll be prefixed to the log file. This is used for hypertune mode with multiple GPUs.
# 2026-07-23 18:37:19,242 - append_to_file = True. If true, logs will be appended to the existing file. If false, the log file will be overwritten.
# 2026-07-23 18:37:19,243 - show_timestamp = True. If true, the printed information will contain a timestamp.
# 2026-07-23 18:37:19,243 -
# 2026-07-23 18:37:19,243 - ### System information ###
# 2026-07-23 18:37:19,244 - Platform: Linux-6.8.0-136-generic-x86_64-with-glibc2.39
# 2026-07-23 18:37:19,244 - Operating System: Linux 6.8.0-136-generic
# 2026-07-23 18:37:19,244 - OS Version: #136-Ubuntu SMP PREEMPT_DYNAMIC Wed Jul  1 21:53:05 UTC 2026
# 2026-07-23 18:37:19,245 - Machine: x86_64
# 2026-07-23 18:37:19,245 - Processor: x86_64
# 2026-07-23 18:37:19,245 - Available CPU cores: 16
# 2026-07-23 18:37:19,247 - Total Memory: 118.01 GB
# 2026-07-23 18:37:19,247 - Available Memory: 111.67 GB
# 2026-07-23 18:37:19,248 -
# 2026-07-23 18:37:19,248 - ### GPU information ###
# 2026-07-23 18:37:19,349 - CUDA Available: True
# 2026-07-23 18:37:19,349 - CUDA Version: 12.8
# 2026-07-23 18:37:19,364 - Available CUDA GPUs: ['NVIDIA RTX A4000']
# 2026-07-23 18:37:19,364 - CUDA Compute Capability: ['8.6']
# 2026-07-23 18:37:19,364 -   INFO: For torch.compile with Triton, you'll need CUDA GPU with Compute Capability >= 7.0.
# 2026-07-23 18:37:19,365 -         In addition, Triton does not directly support Windows.
# 2026-07-23 18:37:19,365 -         For Windows users, please follow the instruction and download `triton-windows` from https://github.com/woct0rdho/triton-windows.
# 2026-07-23 18:37:19,481 - MIG (Multi-Instance GPU) mode = False
# 2026-07-23 18:37:19,481 -   INFO: MIG splits a physical GPU into multiple GPU slices, but multiGPU does not support these MIG slices.
# 2026-07-23 18:37:19,482 -         In addition, multiGPU is currently only available on Linux due to the limited NCCL support.
# 2026-07-23 18:37:19,482 -       -> If you're doing normal reconstruction/hypertune, you can safely ignore this.
# 2026-07-23 18:37:19,482 -       -> If you want to do multiGPU, you must provide multiple 'full' GPUs that are not in MIG mode.
# 2026-07-23 18:37:19,483 -
# 2026-07-23 18:37:19,483 - ### Python information ###
# 2026-07-23 18:37:19,483 - Python Executable: /home/dnz75396/ptyrad/.venv/bin/python
# 2026-07-23 18:37:19,484 - Python Version: 3.12.3 (main, Jun 19 2026, 12:46:00) [GCC 13.3.0]
# 2026-07-23 18:37:19,484 -
# 2026-07-23 18:37:19,484 - ### Packages information ###
# 2026-07-23 18:37:19,486 - Numpy Version (metadata): 2.4.3
# 2026-07-23 18:37:19,488 - PyTorch Version (metadata): 2.10.0
# 2026-07-23 18:37:19,489 - Optuna Version (metadata): 4.8.0
# 2026-07-23 18:37:19,490 - Accelerate Version (metadata): 1.13.0
# 2026-07-23 18:37:19,491 - PtyRAD Version (ptyrad/__init__.py): 0.1.0b12
# 2026-07-23 18:37:19,491 - PtyRAD is located at: /home/dnz75396/ptyrad/src/ptyrad/__init__.py
# 2026-07-23 18:37:19,492 -
# 2026-07-23 18:37:19,492 - ### Loading params file ###
# 2026-07-23 18:37:19,513 - Success! Loaded .yml file path = params/tBL_WSe2_reconstruct_minimal.yml
# 2026-07-23 18:37:19,663 - validate = True: Filling defaults and validating the params file...
# 2026-07-23 18:37:19,666 - Success! Params file validated and defaults applied.
# 2026-07-23 18:37:19,666 -
# 2026-07-23 18:37:19,667 - ### Setting GPU Device ###
# 2026-07-23 18:37:19,667 - Selected GPU device: cuda:0 (NVIDIA RTX A4000)
# 2026-07-23 18:37:19,668 -
# 2026-07-23 18:37:19,668 - ### Initializing Initializer ###
# 2026-07-23 18:37:19,669 - init_params are displayed below:
# 2026-07-23 18:37:19,669 -   random_seed: None
# 2026-07-23 18:37:19,670 -   probe_illum_type: electron
# 2026-07-23 18:37:19,670 -   probe_kv: 80.0
# 2026-07-23 18:37:19,670 -   probe_conv_angle: 24.9
# 2026-07-23 18:37:19,671 -   probe_defocus: 0.0
# 2026-07-23 18:37:19,671 -   probe_c3: 0.0
# 2026-07-23 18:37:19,671 -   probe_c5: 0.0
# 2026-07-23 18:37:19,672 -   beam_kev: None
# 2026-07-23 18:37:19,672 -   probe_dRn: None
# 2026-07-23 18:37:19,672 -   probe_Rn: None
# 2026-07-23 18:37:19,673 -   probe_D_H: None
# 2026-07-23 18:37:19,673 -   probe_D_FZP: None
# 2026-07-23 18:37:19,673 -   probe_Ls: None
# 2026-07-23 18:37:19,674 -   meas_Npix: 128
# 2026-07-23 18:37:19,674 -   pos_N_scans: 16384
# 2026-07-23 18:37:19,674 -   pos_N_scan_slow: 128
# 2026-07-23 18:37:19,675 -   pos_N_scan_fast: 128
# 2026-07-23 18:37:19,675 -   pos_scan_step_size: 0.429
# 2026-07-23 18:37:19,675 -   meas_calibration: {'mode': 'fitRBF', 'value': None}
# 2026-07-23 18:37:19,676 -   probe_pmode_max: 6
# 2026-07-23 18:37:19,676 -   probe_pmode_init_pows: [0.02]
# 2026-07-23 18:37:19,676 -   obj_omode_max: 1
# 2026-07-23 18:37:19,677 -   obj_omode_init_occu: {'occu_type': 'uniform', 'init_occu': None}
# 2026-07-23 18:37:19,677 -   obj_Nlayer: 6
# 2026-07-23 18:37:19,677 -   obj_slice_thickness: 2.0
# 2026-07-23 18:37:19,678 -   meas_permute: None
# 2026-07-23 18:37:19,678 -   meas_reshape: None
# 2026-07-23 18:37:19,678 -   meas_flipT: [1, 0, 0]
# 2026-07-23 18:37:19,679 -   meas_crop: None
# 2026-07-23 18:37:19,679 -   meas_pad: None
# 2026-07-23 18:37:19,679 -   meas_resample: None
# 2026-07-23 18:37:19,680 -   meas_add_source_size: None
# 2026-07-23 18:37:19,680 -   meas_add_detector_blur: None
# 2026-07-23 18:37:19,681 -   meas_remove_neg_values: {'mode': 'clip_neg', 'value': None, 'force': False}
# 2026-07-23 18:37:19,681 -   meas_normalization: {'mode': 'max_at_one', 'value': None}
# 2026-07-23 18:37:19,681 -   meas_add_poisson_noise: None
# 2026-07-23 18:37:19,682 -   meas_export: None
# 2026-07-23 18:37:19,682 -   probe_permute: None
# 2026-07-23 18:37:19,682 -   probe_z_shift: None
# 2026-07-23 18:37:19,683 -   pos_scan_flipT: None
# 2026-07-23 18:37:19,683 -   pos_scan_affine: None
# 2026-07-23 18:37:19,683 -   pos_scan_rand_std: 0.15
# 2026-07-23 18:37:19,684 -   obj_z_crop: None
# 2026-07-23 18:37:19,684 -   obj_z_pad: None
# 2026-07-23 18:37:19,684 -   obj_z_resample: None
# 2026-07-23 18:37:19,685 -   meas_source: file
# 2026-07-23 18:37:19,685 -   meas_params: {'path': 'data/tBL_WSe2/Panel_g-h_Themis/scan_x128_y128.raw', 'key': None, 'shape': None, 'offset': None, 'gap': None}
# 2026-07-23 18:37:19,685 -   probe_source: simu
# 2026-07-23 18:37:19,686 -   probe_params: None
# 2026-07-23 18:37:19,686 -   pos_source: simu
# 2026-07-23 18:37:19,686 -   pos_params: None
# 2026-07-23 18:37:19,687 -   obj_source: simu
# 2026-07-23 18:37:19,687 -   obj_params: None
# 2026-07-23 18:37:19,687 -   tilt_source: simu
# 2026-07-23 18:37:19,688 -   tilt_params: {'tilt_type': 'all', 'init_tilts': [[0, 0]]}
# 2026-07-23 18:37:19,688 -
# 2026-07-23 18:37:19,688 - ### Initializing cache ###
# 2026-07-23 18:37:19,689 - use_cached_obj   = False
# 2026-07-23 18:37:19,689 - use_cached_probe = False
# 2026-07-23 18:37:19,689 - use_cached_pos   = False
# 2026-07-23 18:37:19,690 -
# 2026-07-23 18:37:19,690 - ### Initializing measurements ###
# 2026-07-23 18:37:19,690 - Loading measurements from source = 'file'
# 2026-07-23 18:37:19,691 - Detected measurement file type = '.raw'
# 2026-07-23 18:37:19,691 - WARNING: Couldn't find the 'shape' in 'meas_params' with file type = '.raw'.
# 2026-07-23 18:37:19,691 - It is strongly recommended to provide an explicit shape to better load from .raw files
# 2026-07-23 18:37:19,692 - PtyRAD will still try to load the dataset based on the provided 'init_params', but you may consider setting 'shape': (N_scans, Npix, Npix) inside your 'meas_params' dict.
# Loaded params:  {'init_params': {'random_seed': None, 'probe_illum_type': 'electron', 'probe_kv': 80.0, 'probe_conv_angle': 24.9, 'probe_defocus': 0.0, 'probe_c3': 0.0, 'probe_c5': 0.0, 'beam_kev': None, 'probe_dRn': None, 'probe_Rn': None, 'probe_D_H': None, 'probe_D_FZP': None, 'probe_Ls': None, 'meas_Npix': 128, 'pos_N_scans': 16384, 'pos_N_scan_slow': 128, 'pos_N_scan_fast': 128, 'pos_scan_step_size': 0.429, 'meas_calibration': {'mode': 'fitRBF', 'value': None}, 'probe_pmode_max': 6, 'probe_pmode_init_pows': [0.02], 'obj_omode_max': 1, 'obj_omode_init_occu': {'occu_type': 'uniform', 'init_occu': None}, 'obj_Nlayer': 6, 'obj_slice_thickness': 2.0, 'meas_permute': None, 'meas_reshape': None, 'meas_flipT': [1, 0, 0], 'meas_crop': None, 'meas_pad': None, 'meas_resample': None, 'meas_add_source_size': None, 'meas_add_detector_blur': None, 'meas_remove_neg_values': {'mode': 'clip_neg', 'value': None, 'force': False}, 'meas_normalization': {'mode': 'max_at_one', 'value': None}, 'meas_add_poisson_noise': None, 'meas_export': None, 'probe_permute': None, 'probe_z_shift': None, 'pos_scan_flipT': None, 'pos_scan_affine': None, 'pos_scan_rand_std': 0.15, 'obj_z_crop': None, 'obj_z_pad': None, 'obj_z_resample': None, 'meas_source': 'file', 'meas_params': {'path': 'data/tBL_WSe2/Panel_g-h_Themis/scan_x128_y128.raw', 'key': None, 'shape': None, 'offset': None, 'gap': None}, 'probe_source': 'simu', 'probe_params': None, 'pos_source': 'simu', 'pos_params': None, 'obj_source': 'simu', 'obj_params': None, 'tilt_source': 'simu', 'tilt_params': {'tilt_type': 'all', 'init_tilts': [[0, 0]]}}, 'hypertune_params': {'if_hypertune': False, 'collate_results': True, 'append_params': True, 'n_trials': 5, 'timeout': None, 'sampler_params': {'name': 'TPESampler', 'configs': {'multivariate': True, 'group': True, 'constant_liar': True}}, 'pruner_params': {'name': 'HyperbandPruner', 'configs': {'min_resource': 5, 'reduction_factor': 2}}, 'storage_path': 'sqlite:///hypertune.sqlite3', 'study_name': 'study', 'error_metric': 'loss', 'frc_split_method': 'binomial', 'tune_params': {'optimizer': {'state': False, 'suggest': 'cat', 'kwargs': {'choices': ['Adam', 'AdamW', 'RMSprop', 'SGD'], 'optim_configs': {}}}, 'batch_size': {'state': False, 'suggest': 'int', 'kwargs': {'low': 16, 'high': 512, 'log': True}}, 'plr': {'state': False, 'suggest': 'cat', 'kwargs': {'choices': [0.01, 0.0001, 0.0001]}}, 'oalr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'log': True}}, 'oplr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'log': True}}, 'slr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'log': True}}, 'tlr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'log': True}}, 'dzlr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'log': True}}, 'dx': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.14, 'high': 0.16, 'step': 0.001}}, 'pmode_max': {'state': False, 'suggest': 'int', 'kwargs': {'low': 1, 'high': 8, 'step': 1}}, 'conv_angle': {'state': False, 'suggest': 'float', 'kwargs': {'low': 24, 'high': 26, 'step': 1}}, 'defocus': {'state': False, 'suggest': 'float', 'kwargs': {'low': -50, 'high': 50, 'step': 0.1}}, 'z_shift': {'state': False, 'suggest': 'float', 'kwargs': {'low': -50, 'high': 50, 'step': 10}}, 'c3': {'state': False, 'suggest': 'float', 'kwargs': {'low': 4000, 'high': 10000, 'step': 100}}, 'c5': {'state': False, 'suggest': 'float', 'kwargs': {'low': 50000, 'high': 100000, 'step': 5000}}, 'Nlayer': {'state': False, 'suggest': 'int', 'kwargs': {'low': 1, 'high': 8, 'step': 1}}, 'dz': {'state': False, 'suggest': 'float', 'kwargs': {'low': 4, 'high': 8, 'step': 0.5}}, 'scale': {'state': True, 'suggest': 'float', 'kwargs': {'low': 0.8, 'high': 1.2, 'step': 0.02}}, 'asymmetry': {'state': False, 'suggest': 'float', 'kwargs': {'low': -0.2, 'high': 0.2, 'step': 0.05}}, 'rotation': {'state': True, 'suggest':  ...
# 2026-07-23 18:37:19,908 - Success! Loaded .raw file path = data/tBL_WSe2/Panel_g-h_Themis/scan_x128_y128.raw
# 2026-07-23 18:37:19,908 - Imported .raw data shape = (16384, 128, 128)
# 2026-07-23 18:37:19,909 - Imported .raw data type = float32
# 2026-07-23 18:37:20,080 - Casting measurements dtype to float32 (single precision) for computational efficiency.
# 2026-07-23 18:37:20,081 - Imported meausrements shape / dtype = (16384, 128, 128), dtype = float32
# 2026-07-23 18:37:20,279 - Imported meausrements int. statistics (min, mean, max) = (-30.8785, 1814.7090, 99441.8047)
# 2026-07-23 18:37:20,280 - Flipping measurements with [flipud, fliplr, transpose] = [1, 0, 0]
# 2026-07-23 18:37:20,615 - Removing negative values in measurement with method = clip_neg and value = None
# 2026-07-23 18:37:20,768 - Minimum value = -30.8785, negative values are clipped to 0 due to the positive px value constraint of measurements
# 2026-07-23 18:37:22,313 - Normalizing measurements with mode = 'max_at_one' and value = 'None'
# 2026-07-23 18:37:22,483 - Normalizing by max of the 2D mean pattern intensity: 67097.391
# 2026-07-23 18:37:23,099 - meausrements int. statistics (min, mean, max) = (0.0000, 0.0271, 1.4821)
# 2026-07-23 18:37:23,203 - No negative values found in measurements. Skipping non-neg correction.
# 2026-07-23 18:37:23,455 - meausrements int. statistics (min, mean, max) = (0.0000, 0.0271, 1.4821)
# 2026-07-23 18:37:23,456 - measurements                      (N, Ky, Kx) = float32, (16384, 128, 128)
# 2026-07-23 18:37:23,456 -
# 2026-07-23 18:37:23,457 - ### Setting up calibration ###
# 2026-07-23 18:37:23,457 - meas_calibration mode = 'fitRBF', value = None
# 2026-07-23 18:37:23,458 - Using loaded raw averaged measurement (before crop/pad/resample) to fit RBF as a part of the meas calibration
# 2026-07-23 18:37:23,459 - Radius of fitted bright field disk (RBF) = 11.64 px with Npix = 128
# 2026-07-23 18:37:23,459 - Suggested probe_mask_k radius (RBF*2/Npix) > 0.1819
# 2026-07-23 18:37:23,459 - Fitting raw averaged measurement with center, radius, and Gaussian blur std as a sanity check
# 2026-07-23 18:37:23,460 - Note that the fitted Gaussian blur std (detector blur) would be affected by overlapping Bragg disks
# 2026-07-23 18:37:23,461 - Initial guess: center=(63.78, 63.93), radius=11.64, Gaussian blur std=0.50
# 2026-07-23 18:37:23,472 - Final fit: center=(63.78, 63.93), radius=11.64, Gaussian blur std=0.54
# 2026-07-23 18:37:23,473 - WARNING: The 'fitRBF' and 'RBF' calibration methods are highly dependent on the accuracy of user-provided experimental parameters and acquisition conditions,
# 2026-07-23 18:37:23,473 -          including convergence angle, kV, dose, specimen thickness, and collection angle for the estimation of RBF.
# 2026-07-23 18:37:23,473 -          For example, a 5-10% error in convergence angle is fairly common.
# 2026-07-23 18:37:23,474 -          Users are strongly advised to perform proper microscope calibration to ensure accurate results.
# 2026-07-23 18:37:23,474 -          These method should only be used as a rough estimate and not as a substitute for proper experimental calibration.
# 2026-07-23 18:37:23,475 - dx (real space pixel size of probe and object) set to 0.1526 Ang with Npix = 128
# 2026-07-23 18:37:23,475 -
# 2026-07-23 18:37:23,475 - ### Setting init_variables dict ###
# 2026-07-23 18:37:23,476 - Derived values given input init_params:
# 2026-07-23 18:37:23,476 -   kv          = 80.0 kV
# 2026-07-23 18:37:23,477 -   wavelength  = 0.0418 Ang
# 2026-07-23 18:37:23,477 -   conv_angle  = 24.9 mrad
# 2026-07-23 18:37:23,477 -   Npix        = 128 px
# 2026-07-23 18:37:23,478 -   dk          = 0.0512 Ang^-1
# 2026-07-23 18:37:23,478 -   kMax        = 3.2773 Ang^-1
# 2026-07-23 18:37:23,478 -   da          = 2.1383 mrad
# 2026-07-23 18:37:23,479 -   angleMax    = 136.8515 mrad
# 2026-07-23 18:37:23,479 -   RBF         = 11.6447 px (Inferred from the given calibration, NOT necessarily from the loaded measurement data)
# 2026-07-23 18:37:23,480 -   n_alpha     = 5.4960 (# conv_angle)
# 2026-07-23 18:37:23,480 -   dx          = 0.1526 Ang, Nyquist-limited dmin = 2*dx = 0.3051 Ang
# 2026-07-23 18:37:23,480 -   Rayleigh-limited resolution  = 1.0230 Ang (0.61*lambda/alpha for focused probe )
# 2026-07-23 18:37:23,481 -   Real space probe extent = 19.5282 Ang
# 2026-07-23 18:37:23,481 -
# 2026-07-23 18:37:23,481 - ### Initializing probe ###
# 2026-07-23 18:37:23,482 - Loading probe from source = 'simu'
# 2026-07-23 18:37:23,482 - Using experimental parameters specified by 'init_params' for initial probe simulation.
# 2026-07-23 18:37:23,483 - Start simulating STEM probe
# 2026-07-23 18:37:23,488 -   kv          = 80.0 kV
# 2026-07-23 18:37:23,488 -   wavelength  = 0.0418 Ang
# 2026-07-23 18:37:23,489 -   conv_angle  = 24.9 mrad
# 2026-07-23 18:37:23,489 -   Npix        = 128 px
# 2026-07-23 18:37:23,489 -   dk          = 0.0512 Ang^-1
# 2026-07-23 18:37:23,490 -   kMax        = 3.2773 Ang^-1
# 2026-07-23 18:37:23,490 -   alpha_max   = 136.8467 mrad
# 2026-07-23 18:37:23,491 -   dx          = 0.1526 Ang, Nyquist-limited dmin = 2*dx = 0.3051 Ang
# 2026-07-23 18:37:23,491 -   Rayleigh-limited resolution  = 1.0229 Ang (0.61*lambda/alpha for focused probe )
# 2026-07-23 18:37:23,491 -   Real space probe extent = 19.5282 Ang
# 2026-07-23 18:37:23,492 - Start making mixed-state STEM probe with 6 incoherent probe modes
# 2026-07-23 18:37:23,585 - Relative power of probe modes = [0.9  0.02 0.02 0.02 0.02 0.02]
# 2026-07-23 18:37:23,586 - Loaded probe shape = (6, 128, 128), dtype = complex128
# 2026-07-23 18:37:23,587 - pmode_now: 6 and pmode_max: 6, leaving the pmode unchanged.
# 2026-07-23 18:37:23,589 - Orthogonalizing 6 pmodes
# 2026-07-23 18:37:23,593 - Sorting 6 pmodes by their intensities
# 2026-07-23 18:37:23,596 - sum(|probe_data|**2) = 443.31, while meas.mean(0).sum() = 443.31
# 2026-07-23 18:37:23,597 - probe                         (pmode, Ny, Nx) = complex64, (6, 128, 128)
# 2026-07-23 18:37:23,597 -
# 2026-07-23 18:37:23,597 - ### Initializing probe positions ###
# 2026-07-23 18:37:23,598 - Loading probe positions from source = 'simu'
# 2026-07-23 18:37:23,598 - Using experimental parameters specified by 'init_params' (dx, scan_step size, N_scan_slow, N_scan_fast) for initial position simulation.
# 2026-07-23 18:37:23,599 - Simulating probe positions with dx = 0.1526, scan_step_size = 0.4290, N_scan_fast = 128, N_scan_slow = 128
# 2026-07-23 18:37:23,610 - Applying Gaussian distributed random displacement with std = 0.15 px to scan positions
# 2026-07-23 18:37:23,613 - crop_pos                                (N,2) = int16, (16384, 2)
# 2026-07-23 18:37:23,614 - crop_pos 1st and last px coords (y,x)         = ([49, 50], [407, 406])
# 2026-07-23 18:37:23,615 - crop_pos extent (Ang)                         = [54.61784175 54.61784175]
# 2026-07-23 18:37:23,616 - probe_pos_shifts                        (N,2) = float32, (16384, 2)
# 2026-07-23 18:37:23,616 -
# 2026-07-23 18:37:23,617 - ### Initializing object ###
# 2026-07-23 18:37:23,617 - Loading object from source = 'simu'
# 2026-07-23 18:37:23,618 - Using experimental parameters specified by 'init_params' for initial object simulation.
# 2026-07-23 18:37:23,712 - omode_now: 1 and omode_max: 1, leaving the omode unchanged.
# 2026-07-23 18:37:23,717 - object                    (omode, Nz, Ny, Nx) = complex64, (1, 6, 583, 583)
# 2026-07-23 18:37:23,718 - object extent                 (Z, Y, X) (Ang) = [12.     88.9447 88.9447]
# 2026-07-23 18:37:23,719 -
# 2026-07-23 18:37:23,719 - ### Initializing omode_occu from 'uniform' ###
# 2026-07-23 18:37:23,720 - omode_occu                            (omode) = float32, (1,)
# 2026-07-23 18:37:23,720 -
# 2026-07-23 18:37:23,720 - ### Initializing H (Fresnel propagator) ###
# 2026-07-23 18:37:23,721 - Calculating H with probe_shape = [128. 128.] px, dx = 0.1526 Ang, slice_thickness = 2.0000 Ang, lambd = 0.0418 Ang
# 2026-07-23 18:37:23,722 - H                                    (Ky, Kx) = complex64, (128, 128)
# 2026-07-23 18:37:23,723 -
# 2026-07-23 18:37:23,723 - ### Initializing obj tilts from = 'simu' ###
# 2026-07-23 18:37:23,723 - Initialized obj_tilts with init_tilts = [[0, 0]] (theta_y, theta_x) mrad
# 2026-07-23 18:37:23,724 - obj_tilts                              (N, 2) = float32, (1, 2)
# 2026-07-23 18:37:23,724 -
# 2026-07-23 18:37:23,724 - ### Checking consistency between input params with the initialized variables ###
# 2026-07-23 18:37:23,725 - Npix, DP measurements, probe, and H shapes are consistent as '128'
# 2026-07-23 18:37:23,725 - N_scans, len(meas), N_scan_slow*N_scan_fast, len(crop_pos), and len(probe_pos_shifts) are consistent as '16384'
# 2026-07-23 18:37:23,725 - obj.shape[0] is consistent with len(omode_occu) as '1'
# 2026-07-23 18:37:23,726 - obj.shape[1] is consistent with Nlayer as '6'
# 2026-07-23 18:37:23,728 - crop positions (yx_min=[49 49], yx_max=[535 535]) are well contained inside object canvas (Ny,Nx) = (583, 583).
# 2026-07-23 18:37:23,728 - obj_tilts is consistent with either 1 or N_scans
# 2026-07-23 18:37:23,728 - Pass the consistency check of initialized variables, initialization is done!
# 2026-07-23 18:37:23,729 -
# 2026-07-23 18:37:23,729 - ### Initializing loss function ###
# 2026-07-23 18:37:23,729 - Active loss types:
# 2026-07-23 18:37:23,730 -   loss_single : {'state': True, 'weight': 1.0, 'dp_pow': 0.5}
# 2026-07-23 18:37:23,730 -   loss_sparse : {'state': True, 'weight': 0.1, 'ln_order': 1}
# 2026-07-23 18:37:23,731 -
# 2026-07-23 18:37:23,731 - ### Initializing constraint function ###
# 2026-07-23 18:37:23,731 - Active constraint types:
# 2026-07-23 18:37:23,732 -   ortho_pmode   : {'start_iter': 1, 'step': 1, 'end_iter': None}
# 2026-07-23 18:37:23,732 -   fix_probe_int : {'start_iter': 1, 'step': 1, 'end_iter': None}
# 2026-07-23 18:37:23,732 -   obj_rblur     : {'start_iter': 1, 'step': 1, 'end_iter': None, 'obj_type': 'both', 'kernel_size': 5, 'std': 0.4}
# 2026-07-23 18:37:23,733 -   obj_zblur     : {'start_iter': 1, 'step': 1, 'end_iter': None, 'obj_type': 'both', 'kernel_size': 5, 'std': 1.0}
# 2026-07-23 18:37:23,733 -   mirrored_amp  : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.1, 'scale': 0.03, 'power': 4.0}
# 2026-07-23 18:37:23,733 -   obja_thresh   : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.0, 'thresh': [0.98, 1.02]}
# 2026-07-23 18:37:23,734 -   objp_postiv   : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.0}
# 2026-07-23 18:37:23,734 -
# 2026-07-23 18:37:23,734 - ### Done initializing PtyRADSolver ###
# 2026-07-23 18:37:23,735 -

# %%
ptycho_solver.run()

# Only `reconstruct` mode will return the final reconstructed model, because it's infeasible to store all models in `hypertune` mode and we don't know which model to return in `hypertune` mode
if not ptycho_solver.if_hypertune:
    model = ptycho_solver.reconstruct_results
# Out:
# 2026-07-23 18:37:23,865 - ### Starting the PtyRADSolver in reconstruct mode ###
# 2026-07-23 18:37:23,866 -
# 2026-07-23 18:37:23,866 - ### Initializing PtychoAD model ###
# 2026-07-23 18:37:24,056 - ### PtychoAD optimizable variables ###
# 2026-07-23 18:37:24,056 - obja            : torch.Size([1, 6, 583, 583])    , torch.float32   , device:cuda:0, grad:True , lr:5e-04
# 2026-07-23 18:37:24,057 - objp            : torch.Size([1, 6, 583, 583])    , torch.float32   , device:cuda:0, grad:True , lr:5e-04
# 2026-07-23 18:37:24,057 - obj_tilts       : torch.Size([1, 2])              , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-07-23 18:37:24,057 - slice_thickness : torch.Size([])                  , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-07-23 18:37:24,058 - probe           : torch.Size([6, 128, 128, 2])    , torch.float32   , device:cuda:0, grad:True , lr:1e-04
# 2026-07-23 18:37:24,058 - probe_pos_shifts: torch.Size([16384, 2])          , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-07-23 18:37:24,059 -
# 2026-07-23 18:37:24,059 - ### Optimizable variables statitsics ###
# 2026-07-23 18:37:24,059 - Total measurement values  : 268,435,456
# 2026-07-23 18:37:24,060 - Total optimizing variables: 4,275,276
# 2026-07-23 18:37:24,060 - Overdetermined ratio      : 62.79
# 2026-07-23 18:37:24,060 -
# 2026-07-23 18:37:24,061 - ### Model behavior ###
# 2026-07-23 18:37:24,061 - Obj preblur               : False
# 2026-07-23 18:37:24,061 - Tilt propagator           : False
# 2026-07-23 18:37:24,062 - Change slice thickness    : False
# 2026-07-23 18:37:24,062 - Sub-px probe shift        : False
# 2026-07-23 18:37:24,062 - Detector blur             : False
# 2026-07-23 18:37:24,063 - On-the-fly meas padding   : False
# 2026-07-23 18:37:24,063 - On-the-fly meas resample  : False
# 2026-07-23 18:37:24,063 - Solver type               : born
# 2026-07-23 18:37:24,064 - Born iterations           : 2
# 2026-07-23 18:37:24,064 -
# 2026-07-23 18:37:24,108 - ### Done initializing PtychoAD model ###
# 2026-07-23 18:37:24,109 -
# 2026-07-23 18:37:24,109 - ### Creating PyTorch 'Adam' optimizer with configs = {} ###
# 2026-07-23 18:37:24,110 -
# 2026-07-23 18:37:24,110 - ### Generating indices, batches, and output_path ###
# 2026-07-23 18:37:24,112 - d90 = 23.000 px or 3.509 Ang
# 2026-07-23 18:37:24,113 - Selecting indices with the 'full' mode
# 2026-07-23 18:37:24,559 - Generated 512 'random' groups of ~32 scan positions in 0.001 sec
# 2026-07-23 18:37:25,543 - The effective batch size (i.e., how many probe positions are simultaneously used for 1 update of ptychographic parameters) is batch_size * grad_accumulation = 32 * 1 = 32
# 2026-07-23 18:37:25,544 - Original recon_dir_affixes = ['default']
# 2026-07-23 18:37:25,544 - Expanded recon_dir_affixes = ['indices', 'meas', 'batch', 'pmode', 'omode', 'nlayer', 'lr', 'model', 'constraint', 'loss', 'affine', 'tilt']
# 2026-07-23 18:37:25,551 - output_path = '/home/dnz75396/ptyrad/demo/output/tBL_WSe2_full/20260723_full_N16384_dp128_flipT100_random32_p6_1obj_6slice_dz2_plr1e-4_oalr5e-4_oplr5e-4_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.98_oposc_sng1.0_spr0.1' is generated!
# 2026-07-23 18:37:27,794 -
# 2026-07-23 18:37:27,794 - ### Successfully copy 'tBL_WSe2_reconstruct_minimal.yml' to '/home/dnz75396/ptyrad/demo/output/tBL_WSe2_full/20260723_full_N16384_dp128_flipT100_random32_p6_1obj_6slice_dz2_plr1e-4_oalr5e-4_oplr5e-4_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.98_oposc_sng1.0_spr0.1' ###
# 2026-07-23 18:37:27,795 -
# 2026-07-23 18:37:27,796 - ### Log file is flushed (created) as /home/dnz75396/ptyrad/demo/output/tBL_WSe2_full/20260723_full_N16384_dp128_flipT100_random32_p6_1obj_6slice_dz2_plr1e-4_oalr5e-4_oplr5e-4_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.98_oposc_sng1.0_spr0.1/20260723_183727_ptyrad_log.txt ###
# 2026-07-23 18:37:27,796 -
# 2026-07-23 18:37:27,797 - ### Start the PtyRAD iterative ptycho reconstruction ###
# 2026-07-23 18:37:27,797 -
# 2026-07-23 18:37:27,797 - Iter: 1, obja.requires_grad = True
# 2026-07-23 18:37:27,798 - Iter: 1, objp.requires_grad = True
# 2026-07-23 18:37:27,798 - Iter: 1, obj_tilts.requires_grad = False
# 2026-07-23 18:37:27,799 - Iter: 1, slice_thickness.requires_grad = False
# 2026-07-23 18:37:27,799 - Iter: 1, probe.requires_grad = True
# 2026-07-23 18:37:27,799 - Iter: 1, probe_pos_shifts.requires_grad = False
# 2026-07-23 18:37:27,800 - Setting up PyTorch compiler with {'fullgraph': False, 'dynamic': None, 'backend': 'inductor', 'mode': 'default', 'options': None, 'disable': True}
# 2026-07-23 18:37:39,308 - Done batch 1 with 32 indices ([1839, 14933, 13907, 6542, 11815]...) in 11.503 sec
# 2026-07-23 18:37:43,002 - Done batch 103 with 32 indices ([4260, 12340, 11734, 16240, 4462]...) in 0.035 sec
# 2026-07-23 18:37:46,643 - Done batch 205 with 32 indices ([6544, 1838, 9008, 6710, 394]...) in 0.035 sec
# 2026-07-23 18:37:50,287 - Done batch 307 with 32 indices ([7946, 16340, 6995, 2188, 3700]...) in 0.036 sec
# 2026-07-23 18:37:53,931 - Done batch 409 with 32 indices ([6482, 14678, 16009, 4110, 13547]...) in 0.036 sec
# 2026-07-23 18:37:57,610 - Done batch 512 with 32 indices ([11537, 2436, 10579, 14095, 10523]...) in 0.036 sec
# 2026-07-23 18:37:57,691 - Apply ortho pmode constraint at iter 1, relative pmode power = [0.892 0.033 0.029 0.02  0.015 0.012], probe int sum = 457.8577
# 2026-07-23 18:37:57,692 - Apply fix probe int constraint at iter 1, probe int sum = 443.3113
# 2026-07-23 18:37:57,739 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 1
# 2026-07-23 18:37:57,740 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 1
# 2026-07-23 18:37:57,917 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 1
# 2026-07-23 18:37:57,919 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 1
# 2026-07-23 18:37:57,933 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 1. obja range becomes (0.996, 1.004)
# 2026-07-23 18:37:57,934 - Apply hard threshold constraint with thresh = [0.98, 1.02] on obja at iter 1
# 2026-07-23 18:37:57,935 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 1. Original min = -0.043. objp range becomes (0.000, 0.046)
# 2026-07-23 18:37:57,937 - Iter: 1, Total Loss: 0.4716, loss_single: 0.4711, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0005, loss_simlar: 0.0000, in 30.132 sec
# 2026-07-23 18:37:57,937 -
# 2026-07-23 18:37:57,938 - Iter: 2, obja.requires_grad = True
# 2026-07-23 18:37:57,938 - Iter: 2, objp.requires_grad = True
# 2026-07-23 18:37:57,939 - Iter: 2, obj_tilts.requires_grad = False
# 2026-07-23 18:37:57,939 - Iter: 2, slice_thickness.requires_grad = False
# 2026-07-23 18:37:57,940 - Iter: 2, probe.requires_grad = True
# 2026-07-23 18:37:57,940 - Iter: 2, probe_pos_shifts.requires_grad = False
# 2026-07-23 18:37:57,978 - Done batch 1 with 32 indices ([1839, 14933, 13907, 6542, 11815]...) in 0.036 sec
# 2026-07-23 18:38:01,622 - Done batch 103 with 32 indices ([4260, 12340, 11734, 16240, 4462]...) in 0.035 sec
# 2026-07-23 18:38:05,269 - Done batch 205 with 32 indices ([6544, 1838, 9008, 6710, 394]...) in 0.035 sec
# 2026-07-23 18:38:08,921 - Done batch 307 with 32 indices ([7946, 16340, 6995, 2188, 3700]...) in 0.036 sec
# 2026-07-23 18:38:12,570 - Done batch 409 with 32 indices ([6482, 14678, 16009, 4110, 13547]...) in 0.036 sec
# 2026-07-23 18:38:16,258 - Done batch 512 with 32 indices ([11537, 2436, 10579, 14095, 10523]...) in 0.036 sec
# 2026-07-23 18:38:16,261 - Apply ortho pmode constraint at iter 2, relative pmode power = [0.893 0.032 0.028 0.02  0.015 0.012], probe int sum = 441.9924
# 2026-07-23 18:38:16,262 - Apply fix probe int constraint at iter 2, probe int sum = 443.3112
# 2026-07-23 18:38:16,263 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 2
# 2026-07-23 18:38:16,264 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 2
# 2026-07-23 18:38:16,265 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 2
# 2026-07-23 18:38:16,266 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 2
# 2026-07-23 18:38:16,267 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 2. obja range becomes (0.996, 1.004)
# 2026-07-23 18:38:16,268 - Apply hard threshold constraint with thresh = [0.98, 1.02] on obja at iter 2
# 2026-07-23 18:38:16,268 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 2. Original min = -0.031. objp range becomes (0.000, 0.078)
# 2026-07-23 18:38:16,270 - Iter: 2, Total Loss: 0.4026, loss_single: 0.4021, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0005, loss_simlar: 0.0000, in 18.328 sec
# 2026-07-23 18:38:16,272 -
# 2026-07-23 18:38:16,272 - Iter: 3, obja.requires_grad = True
# 2026-07-23 18:38:16,273 - Iter: 3, objp.requires_grad = True
# 2026-07-23 18:38:16,273 - Iter: 3, obj_tilts.requires_grad = False
# 2026-07-23 18:38:16,274 - Iter: 3, slice_thickness.requires_grad = False
# 2026-07-23 18:38:16,274 - Iter: 3, probe.requires_grad = True
# 2026-07-23 18:38:16,274 - Iter: 3, probe_pos_shifts.requires_grad = False
# 2026-07-23 18:38:16,311 - Done batch 1 with 32 indices ([1839, 14933, 13907, 6542, 11815]...) in 0.036 sec
# 2026-07-23 18:38:19,963 - Done batch 103 with 32 indices ([4260, 12340, 11734, 16240, 4462]...) in 0.036 sec
# 2026-07-23 18:38:23,621 - Done batch 205 with 32 indices ([6544, 1838, 9008, 6710, 394]...) in 0.036 sec
# 2026-07-23 18:38:27,279 - Done batch 307 with 32 indices ([7946, 16340, 6995, 2188, 3700]...) in 0.036 sec
# 2026-07-23 18:38:30,935 - Done batch 409 with 32 indices ([6482, 14678, 16009, 4110, 13547]...) in 0.036 sec
# 2026-07-23 18:38:34,635 - Done batch 512 with 32 indices ([11537, 2436, 10579, 14095, 10523]...) in 0.036 sec
# 2026-07-23 18:38:34,638 - Apply ortho pmode constraint at iter 3, relative pmode power = [0.893 0.032 0.028 0.02  0.015 0.012], probe int sum = 441.5873
# 2026-07-23 18:38:34,639 - Apply fix probe int constraint at iter 3, probe int sum = 443.3112
# 2026-07-23 18:38:34,640 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 3
# 2026-07-23 18:38:34,641 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 3
# 2026-07-23 18:38:34,642 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 3
# 2026-07-23 18:38:34,644 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 3
# 2026-07-23 18:38:34,645 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 3. obja range becomes (0.996, 1.004)
# 2026-07-23 18:38:34,645 - Apply hard threshold constraint with thresh = [0.98, 1.02] on obja at iter 3
# 2026-07-23 18:38:34,646 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 3. Original min = -0.030. objp range becomes (0.000, 0.099)
# 2026-07-23 18:38:34,647 - Iter: 3, Total Loss: 0.4011, loss_single: 0.4005, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0006, loss_simlar: 0.0000, in 18.372 sec
# 2026-07-23 18:38:34,650 -
# 2026-07-23 18:38:34,650 - Iter: 4, obja.requires_grad = True
# 2026-07-23 18:38:34,651 - Iter: 4, objp.requires_grad = True
# 2026-07-23 18:38:34,651 - Iter: 4, obj_tilts.requires_grad = False
# 2026-07-23 18:38:34,652 - Iter: 4, slice_thickness.requires_grad = False
# 2026-07-23 18:38:34,652 - Iter: 4, probe.requires_grad = True
# 2026-07-23 18:38:34,652 - Iter: 4, probe_pos_shifts.requires_grad = False
# 2026-07-23 18:38:34,690 - Done batch 1 with 32 indices ([1839, 14933, 13907, 6542, 11815]...) in 0.036 sec
# 2026-07-23 18:38:38,347 - Done batch 103 with 32 indices ([4260, 12340, 11734, 16240, 4462]...) in 0.036 sec
