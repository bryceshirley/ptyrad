# %% [markdown]
# # Quick example for PtyRAD
#
# - Created with PtyRAD 0.1.0b8
# - Requires PtyRAD >= 0.1.0b8
# - Latest demo params files / scripts: https://github.com/chiahao3/ptyrad/tree/main/demo
# - Documentation: https://ptyrad.readthedocs.io/en/latest/
# - PtyRAD paper: https://doi.org/10.1093/mam/ozaf070
# - PtyRAD arXiv: https://arxiv.org/abs/2505.07814
# - Zenodo record: https://doi.org/10.5281/zenodo.15273176
# - Box folder: https://cornell.box.com/s/n5balzf88jixescp9l15ojx7di4xn1uo
# - Youtube channel: https://www.youtube.com/@ptyrad_official
#
# **Before running this notebook, you must first follow the instruction in `README.md` to:**
# 1. Create the Python environment with all dependant Python packages like PyTorch
# 2. Activate that python environment
# 3. Install `ptyrad` package into your activated Python environement (only need to install once)
# 4. Download the demo data into `demo/data/` from the `demo/data/data_url.txt`
#
# > Note: This notebook is designed for "ease of operation with the solver class `PtyRADSolver`", both "reconstruction" and "hypertune" modes are supported.
#
# Author: Chia-Hao Lee, cl2696@cornell.edu

# %%
import os

# Change this to the ABSOLUTE PATH to the demo/ folder so you can correctly access data/ and params/
work_dir = "../"  # Leave this as-is if you're running the notebook from the `ptyrad/demo/scripts/` folder, this will change it back to demo/

os.chdir(work_dir)
print("Current working dir: ", os.getcwd())
# The printed working dir should be ".../ptyrad/demo" to locate the demo params files easily
# Note that the output/ directory will be automatically generated under your working directory
# Out:
# Current working dir:  /home/dnz75396/ptyrad/demo

# %%
from ptyrad.load import load_params
from ptyrad.reconstruction import PtyRADSolver
from ptyrad.utils import CustomLogger, print_system_info, set_gpu_device

logger = CustomLogger(
    log_file="ptyrad_log.txt", log_dir="auto", prefix_time="datetime", show_timestamp=True
)

# All the following params files are provided in demo/params/ and we're using relative path here
# So if you change the working directory, or have moved params files around, you'll have to provide absolute path to the params file

# params_path = "params/tBL_WSe2_reconstruct_minimal.yml"
# params_path = "params/tBL_WSe2_reconstruct.yml"
params_path = "params/PSO_reconstruct.yml"
# params_path = (
#     "params/tBL_WSe2_tuned.yml"  # This will run PtyRAD with the hyperparameter tuning mode
# )

print_system_info()

# We enable validation to auto-fill defaults and check parameter consistency since PtyRAD 0.1.0b8
# If you run into issues with validation (e.g., false positives or unexpected errors),
# you can temporarily disable it by setting `validate=False` and prepare a fully complete params file yourself.
# If this happens, please report the bug so we can improve the validation logic.
params = load_params(params_path, validate=True)

print("Loaded params: ", params)
device = set_gpu_device(
    gpuid=0
)  # Pass in `gpuid = None` if you don't have access to a CUDA-compatible GPU. Note that running PtyRAD with CPU would be much slower than on GPU.

ptycho_solver = PtyRADSolver(params, device=device, logger=logger)
# Out:
# 2026-05-12 15:56:40,287 - ### PtyRAD Logger configuration ###
# 2026-05-12 15:56:40,289 - log_file       = 'ptyrad_log.txt'. If log_file = None, no log file will be created.
# 2026-05-12 15:56:40,289 - log_dir        = 'auto'. If log_dir = 'auto', then log will be saved to `output_path` or 'logs/'.
# 2026-05-12 15:56:40,289 - flush_file     = True. Automatically set to True if `log_file is not None`
# 2026-05-12 15:56:40,290 - prefix_time    = datetime. If true, preset strings ('date', 'time', 'datetime'), or a string of time format, a datetime str is prefixed to the `log_file`.
# 2026-05-12 15:56:40,290 - prefix_jobid   = '0'. If not 0, it'll be prefixed to the log file. This is used for hypertune mode with multiple GPUs.
# 2026-05-12 15:56:40,290 - append_to_file = True. If true, logs will be appended to the existing file. If false, the log file will be overwritten.
# 2026-05-12 15:56:40,291 - show_timestamp = True. If true, the printed information will contain a timestamp.
# 2026-05-12 15:56:40,291 -
# 2026-05-12 15:56:40,292 - ### System information ###
# 2026-05-12 15:56:40,292 - Platform: Linux-6.8.0-90-generic-x86_64-with-glibc2.39
# 2026-05-12 15:56:40,292 - Operating System: Linux 6.8.0-90-generic
# 2026-05-12 15:56:40,293 - OS Version: #91-Ubuntu SMP PREEMPT_DYNAMIC Tue Nov 18 14:14:30 UTC 2025
# 2026-05-12 15:56:40,294 - Machine: x86_64
# 2026-05-12 15:56:40,294 - Processor: x86_64
# 2026-05-12 15:56:40,295 - Available CPU cores: 124
# 2026-05-12 15:56:40,295 - Total Memory: 885.78 GB
# 2026-05-12 15:56:40,296 - Available Memory: 868.76 GB
# 2026-05-12 15:56:40,296 -
# 2026-05-12 15:56:40,297 - ### GPU information ###
# 2026-05-12 15:56:40,364 - CUDA Available: True
# 2026-05-12 15:56:40,364 - CUDA Version: 12.8
# 2026-05-12 15:56:40,413 - Available CUDA GPUs: ['NVIDIA A100 80GB PCIe', 'NVIDIA A100 80GB PCIe', 'NVIDIA A100 80GB PCIe', 'NVIDIA A100 80GB PCIe']
# 2026-05-12 15:56:40,414 - CUDA Compute Capability: ['8.0', '8.0', '8.0', '8.0']
# 2026-05-12 15:56:40,415 -   INFO: For torch.compile with Triton, you'll need CUDA GPU with Compute Capability >= 7.0.
# 2026-05-12 15:56:40,415 -         In addition, Triton does not directly support Windows.
# 2026-05-12 15:56:40,415 -         For Windows users, please follow the instruction and download `triton-windows` from https://github.com/woct0rdho/triton-windows.
# 2026-05-12 15:56:40,463 - MIG (Multi-Instance GPU) mode = False
# 2026-05-12 15:56:40,464 -   INFO: MIG splits a physical GPU into multiple GPU slices, but multiGPU does not support these MIG slices.
# 2026-05-12 15:56:40,465 -         In addition, multiGPU is currently only available on Linux due to the limited NCCL support.
# 2026-05-12 15:56:40,465 -       -> If you're doing normal reconstruction/hypertune, you can safely ignore this.
# 2026-05-12 15:56:40,465 -       -> If you want to do multiGPU, you must provide multiple 'full' GPUs that are not in MIG mode.
# 2026-05-12 15:56:40,466 -
# 2026-05-12 15:56:40,466 - ### Python information ###
# 2026-05-12 15:56:40,466 - Python Executable: /home/dnz75396/ptyrad/.venv/bin/python
# 2026-05-12 15:56:40,467 - Python Version: 3.13.12 | packaged by Anaconda, Inc. | (main, Feb 24 2026, 16:13:31) [GCC 14.3.0]
# 2026-05-12 15:56:40,467 -
# 2026-05-12 15:56:40,467 - ### Packages information ###
# 2026-05-12 15:56:40,469 - Numpy Version (metadata): 2.4.3
# 2026-05-12 15:56:40,471 - PyTorch Version (metadata): 2.10.0
# 2026-05-12 15:56:40,472 - Optuna Version (metadata): 4.8.0
# 2026-05-12 15:56:40,473 - Accelerate Version (metadata): 1.13.0
# 2026-05-12 15:56:40,474 - PtyRAD Version (ptyrad/__init__.py): 0.1.0b12
# 2026-05-12 15:56:40,474 - PtyRAD is located at: /home/dnz75396/ptyrad/src/ptyrad/__init__.py
# 2026-05-12 15:56:40,475 -
# 2026-05-12 15:56:40,475 - ### Loading params file ###
# 2026-05-12 15:56:40,534 - Success! Loaded .yml file path = params/PSO_reconstruct.yml
# 2026-05-12 15:56:40,534 - WARNING: For constraint_params, 'freq' is depracated since PtyRAD v0.1.0b11 and is automatically converted to 'step'.
# 2026-05-12 15:56:40,679 - validate = True: Filling defaults and validating the params file...
# 2026-05-12 15:56:40,680 - Success! Params file validated and defaults applied.
# 2026-05-12 15:56:40,681 -
# 2026-05-12 15:56:40,682 - ### Setting GPU Device ###
# 2026-05-12 15:56:40,682 - Selected GPU device: cuda:0 (NVIDIA A100 80GB PCIe)
# 2026-05-12 15:56:40,683 -
# 2026-05-12 15:56:40,684 - ### Initializing Initializer ###
# 2026-05-12 15:56:40,684 - init_params are displayed below:
# 2026-05-12 15:56:40,684 -   random_seed: None
# 2026-05-12 15:56:40,685 -   probe_illum_type: electron
# 2026-05-12 15:56:40,685 -   probe_kv: 300.0
# 2026-05-12 15:56:40,685 -   probe_conv_angle: 21.4
# 2026-05-12 15:56:40,686 -   probe_defocus: -200.0
# 2026-05-12 15:56:40,686 -   probe_c3: 0.0
# 2026-05-12 15:56:40,686 -   probe_c5: 0.0
# 2026-05-12 15:56:40,687 -   beam_kev: None
# 2026-05-12 15:56:40,687 -   probe_dRn: None
# 2026-05-12 15:56:40,687 -   probe_Rn: None
# 2026-05-12 15:56:40,688 -   probe_D_H: None
# 2026-05-12 15:56:40,688 -   probe_D_FZP: None
# 2026-05-12 15:56:40,690 -   probe_Ls: None
# 2026-05-12 15:56:40,690 -   meas_Npix: 256
# 2026-05-12 15:56:40,690 -   pos_N_scans: 4096
# 2026-05-12 15:56:40,691 -   pos_N_scan_slow: 64
# 2026-05-12 15:56:40,691 -   pos_N_scan_fast: 64
# 2026-05-12 15:56:40,692 -   pos_scan_step_size: 0.41
# 2026-05-12 15:56:40,692 -   meas_calibration: {'mode': 'fitRBF', 'value': None}
# 2026-05-12 15:56:40,692 -   probe_pmode_max: 4
# 2026-05-12 15:56:40,693 -   probe_pmode_init_pows: [0.02]
# 2026-05-12 15:56:40,693 -   obj_omode_max: 1
# 2026-05-12 15:56:40,693 -   obj_omode_init_occu: {'occu_type': 'uniform', 'init_occu': None}
# 2026-05-12 15:56:40,694 -   obj_Nlayer: 21
# 2026-05-12 15:56:40,694 -   obj_slice_thickness: 10.0
# 2026-05-12 15:56:40,695 -   meas_permute: None
# 2026-05-12 15:56:40,695 -   meas_reshape: None
# 2026-05-12 15:56:40,695 -   meas_flipT: None
# 2026-05-12 15:56:40,696 -   meas_crop: [None, None, [68, 188], [68, 188]]
# 2026-05-12 15:56:40,696 -   meas_pad: {'mode': 'on_the_fly', 'padding_type': 'power', 'target_Npix': 256, 'value': 0.0, 'threshold': 70}
# 2026-05-12 15:56:40,697 -   meas_resample: {'mode': None, 'scale_factors': [2.0, 2.0]}
# 2026-05-12 15:56:40,697 -   meas_add_source_size: None
# 2026-05-12 15:56:40,697 -   meas_add_detector_blur: None
# 2026-05-12 15:56:40,698 -   meas_remove_neg_values: {'mode': 'clip_neg', 'value': None, 'force': False}
# 2026-05-12 15:56:40,698 -   meas_normalization: {'mode': 'max_at_one', 'value': None}
# 2026-05-12 15:56:40,698 -   meas_add_poisson_noise: None
# 2026-05-12 15:56:40,699 -   meas_export: None
# 2026-05-12 15:56:40,699 -   probe_permute: None
# 2026-05-12 15:56:40,700 -   probe_z_shift: None
# 2026-05-12 15:56:40,700 -   pos_scan_flipT: None
# 2026-05-12 15:56:40,700 -   pos_scan_affine: None
# 2026-05-12 15:56:40,701 -   pos_scan_rand_std: 0.15
# 2026-05-12 15:56:40,701 -   obj_z_crop: None
# 2026-05-12 15:56:40,701 -   obj_z_pad: None
# 2026-05-12 15:56:40,702 -   obj_z_resample: None
# 2026-05-12 15:56:40,702 -   meas_source: file
# 2026-05-12 15:56:40,703 -   meas_params: {'path': 'data/PSO/sample_data_PrScO3.mat', 'key': 'dp', 'shape': None, 'offset': None, 'gap': None}
# 2026-05-12 15:56:40,703 -   probe_source: simu
# 2026-05-12 15:56:40,704 -   probe_params: None
# 2026-05-12 15:56:40,704 -   pos_source: simu
# 2026-05-12 15:56:40,704 -   pos_params: None
# 2026-05-12 15:56:40,705 -   obj_source: simu
# 2026-05-12 15:56:40,705 -   obj_params: None
# 2026-05-12 15:56:40,705 -   tilt_source: simu
# 2026-05-12 15:56:40,706 -   tilt_params: {'tilt_type': 'all', 'init_tilts': [[0.0, 0.0]]}
# 2026-05-12 15:56:40,706 -
# 2026-05-12 15:56:40,707 - ### Initializing cache ###
# 2026-05-12 15:56:40,707 - use_cached_obj   = False
# 2026-05-12 15:56:40,707 - use_cached_probe = False
# 2026-05-12 15:56:40,708 - use_cached_pos   = False
# 2026-05-12 15:56:40,708 -
# 2026-05-12 15:56:40,709 - ### Initializing measurements ###
# 2026-05-12 15:56:40,709 - Loading measurements from source = 'file'
# 2026-05-12 15:56:40,709 - Detected measurement file type = '.mat'
# 2026-05-12 15:56:40,710 - Detected .mat v7.3 (HDF5 format). Delegating to `load_hdf5`.
# Loaded params:  {'init_params': {'random_seed': None, 'probe_illum_type': 'electron', 'probe_kv': 300.0, 'probe_conv_angle': 21.4, 'probe_defocus': -200.0, 'probe_c3': 0.0, 'probe_c5': 0.0, 'beam_kev': None, 'probe_dRn': None, 'probe_Rn': None, 'probe_D_H': None, 'probe_D_FZP': None, 'probe_Ls': None, 'meas_Npix': 256, 'pos_N_scans': 4096, 'pos_N_scan_slow': 64, 'pos_N_scan_fast': 64, 'pos_scan_step_size': 0.41, 'meas_calibration': {'mode': 'fitRBF', 'value': None}, 'probe_pmode_max': 4, 'probe_pmode_init_pows': [0.02], 'obj_omode_max': 1, 'obj_omode_init_occu': {'occu_type': 'uniform', 'init_occu': None}, 'obj_Nlayer': 21, 'obj_slice_thickness': 10.0, 'meas_permute': None, 'meas_reshape': None, 'meas_flipT': None, 'meas_crop': [None, None, [68, 188], [68, 188]], 'meas_pad': {'mode': 'on_the_fly', 'padding_type': 'power', 'target_Npix': 256, 'value': 0.0, 'threshold': 70}, 'meas_resample': {'mode': None, 'scale_factors': [2.0, 2.0]}, 'meas_add_source_size': None, 'meas_add_detector_blur': None, 'meas_remove_neg_values': {'mode': 'clip_neg', 'value': None, 'force': False}, 'meas_normalization': {'mode': 'max_at_one', 'value': None}, 'meas_add_poisson_noise': None, 'meas_export': None, 'probe_permute': None, 'probe_z_shift': None, 'pos_scan_flipT': None, 'pos_scan_affine': None, 'pos_scan_rand_std': 0.15, 'obj_z_crop': None, 'obj_z_pad': None, 'obj_z_resample': None, 'meas_source': 'file', 'meas_params': {'path': 'data/PSO/sample_data_PrScO3.mat', 'key': 'dp', 'shape': None, 'offset': None, 'gap': None}, 'probe_source': 'simu', 'probe_params': None, 'pos_source': 'simu', 'pos_params': None, 'obj_source': 'simu', 'obj_params': None, 'tilt_source': 'simu', 'tilt_params': {'tilt_type': 'all', 'init_tilts': [[0.0, 0.0]]}}, 'hypertune_params': {'if_hypertune': False, 'collate_results': True, 'append_params': True, 'n_trials': 5, 'timeout': None, 'sampler_params': {'name': 'TPESampler', 'configs': {'multivariate': True, 'group': True, 'constant_liar': True}}, 'pruner_params': {'name': 'HyperbandPruner', 'configs': {'min_resource': 5, 'reduction_factor': 2}}, 'storage_path': 'sqlite:///hypertune.sqlite3', 'study_name': 'PSO', 'error_metric': 'loss', 'frc_split_method': 'binomial', 'tune_params': {'optimizer': {'state': False, 'suggest': 'cat', 'kwargs': {'choices': ['Adam', 'AdamW', 'RMSprop', 'SGD'], 'optim_configs': {}}}, 'batch_size': {'state': False, 'suggest': 'int', 'kwargs': {'low': 16, 'high': 512, 'log': True}}, 'plr': {'state': False, 'suggest': 'cat', 'kwargs': {'choices': [0.01, 0.0001, 0.0001]}}, 'oalr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'oplr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'slr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'tlr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'dzlr': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.0001, 'high': 0.01, 'step': None, 'log': True}}, 'dx': {'state': False, 'suggest': 'float', 'kwargs': {'low': 0.14, 'high': 0.16, 'step': None, 'log': False}}, 'pmode_max': {'state': False, 'suggest': 'int', 'kwargs': {'low': 1, 'high': 8, 'step': 1, 'log': False}}, 'conv_angle': {'state': False, 'suggest': 'float', 'kwargs': {'low': 24, 'high': 26, 'step': 1, 'log': False}}, 'defocus': {'state': False, 'suggest': 'float', 'kwargs': {'low': -50, 'high': 50, 'step': 0.1, 'log': False}}, 'z_shift': {'state': False, 'suggest': 'float', 'kwargs': {'low': -50, 'high': 50, 'step': 10}}, 'c3': {'state': False, 'suggest': 'float', 'kwargs': {'low': 4000, 'high': 10000, 'step': None, 'log': False}}, 'c5': {'state': False, 'suggest': 'float', 'kwargs': {'low': 50000, 'high': 100000, 'step': 5000, 'log': False}}, 'Nlayer': {'state': False, 'suggest': 'int', 'kwargs': {'low': 1, 'high': 8, 'step': 1, 'log': False}}, 'dz': {'state': F ...
# 2026-05-12 15:56:45,014 - Success! Loaded .hdf5 file with key = 'dp' from path = 'data/PSO/sample_data_PrScO3.mat'
# 2026-05-12 15:56:45,016 - Imported .hdf5 data shape = (4096, 256, 256)
# 2026-05-12 15:56:45,017 - Imported .hdf5 data type = float64
# 2026-05-12 15:56:45,257 - Casting measurements dtype to float32 (single precision) for computational efficiency.
# 2026-05-12 15:56:45,259 - Imported meausrements shape / dtype = (4096, 256, 256), dtype = float32
# 2026-05-12 15:56:45,431 - Imported meausrements int. statistics (min, mean, max) = (0.0000, 3.1329, 416.8463)
# 2026-05-12 15:56:45,486 - Reshaping measurements into (64, 64, 256, 256) for cropping
# 2026-05-12 15:56:45,487 - Cropping axis ky from 68 to 188
# 2026-05-12 15:56:45,488 - Cropping axis kx from 68 to 188
# 2026-05-12 15:56:45,488 - Cropped measurements have shape (N_slow, N_fast, ky, kx) = (64, 64, 120, 120)
# 2026-05-12 15:56:45,488 - Update (Npix, N_scans, N_scan_slow, N_scan_fast) after the measurements cropping
# 2026-05-12 15:56:45,489 - Reshape measurements back to (N, ky, kx) = (4096, 120, 120)
# 2026-05-12 15:56:45,535 - No negative values found in measurements. Skipping non-neg correction.
# 2026-05-12 15:56:45,536 - Normalizing measurements with mode = 'max_at_one' and value = 'None'
# 2026-05-12 15:56:45,580 - Normalizing by max of the 2D mean pattern intensity: 91.590782
# 2026-05-12 15:56:45,726 - meausrements int. statistics (min, mean, max) = (0.0000, 0.1555, 4.5512)
# 2026-05-12 15:56:45,727 - Padding measurements with mode='on_the_fly', padding_type='power', target_Npix=256
# 2026-05-12 15:56:45,742 - Using percentile = 70.00% to create an one-hot mask for measurements amplitude background fitting
# 2026-05-12 15:56:45,743 - The mask has roughly 37.08 px in radius, or 0.62 of the distance from center to edge of the image
# 2026-05-12 15:56:45,797 - Fitted a = 23.8710, b = 1.3862 for power law decay: y = a*r^-b
# 2026-05-12 15:56:45,799 - Original meas int sum = 2239.2568, padded region int sum = 80.0559, or 3.58% more intensity after padding.
# 2026-05-12 15:56:45,800 - This percentage should be ideally less than 5%, or you should set a lower threshold to exclude more central region.
# 2026-05-12 15:56:45,800 - Update Npix after the measurements padding
# 2026-05-12 15:56:45,823 - No negative values found in measurements. Skipping non-neg correction.
# 2026-05-12 15:56:45,845 - Adjusting `meas_avg_sum` by adding 80.0559 for on_the_fly meas padding
# 2026-05-12 15:56:45,890 - meausrements int. statistics (min, mean, max) = (0.0000, 0.1555, 4.5512)
# 2026-05-12 15:56:45,891 - measurements                      (N, Ky, Kx) = float32, (4096, 120, 120)
# 2026-05-12 15:56:45,891 -
# 2026-05-12 15:56:45,892 - ### Setting up calibration ###
# 2026-05-12 15:56:45,892 - meas_calibration mode = 'fitRBF', value = None
# 2026-05-12 15:56:45,893 - Using loaded raw averaged measurement (before crop/pad/resample) to fit RBF as a part of the meas calibration
# 2026-05-12 15:56:45,894 - Radius of fitted bright field disk (RBF) = 26.04 px with Npix = 256
# 2026-05-12 15:56:45,894 - Suggested probe_mask_k radius (RBF*2/Npix) > 0.2035
# 2026-05-12 15:56:45,894 - Fitting raw averaged measurement with center, radius, and Gaussian blur std as a sanity check
# 2026-05-12 15:56:45,895 - Note that the fitted Gaussian blur std (detector blur) would be affected by overlapping Bragg disks
# 2026-05-12 15:56:45,896 - Initial guess: center=(127.49, 127.84), radius=26.04, Gaussian blur std=0.50
# 2026-05-12 15:56:45,967 - Final fit: center=(127.49, 127.84), radius=26.04, Gaussian blur std=2.73
# 2026-05-12 15:56:45,967 - WARNING: The 'fitRBF' and 'RBF' calibration methods are highly dependent on the accuracy of user-provided experimental parameters and acquisition conditions,
# 2026-05-12 15:56:45,968 -          including convergence angle, kV, dose, specimen thickness, and collection angle for the estimation of RBF.
# 2026-05-12 15:56:45,968 -          For example, a 5-10% error in convergence angle is fairly common.
# 2026-05-12 15:56:45,968 -          Users are strongly advised to perform proper microscope calibration to ensure accurate results.
# 2026-05-12 15:56:45,969 -          These method should only be used as a rough estimate and not as a substitute for proper experimental calibration.
# 2026-05-12 15:56:45,969 - dx (real space pixel size of probe and object) set to 0.0936 Ang with Npix = 256
# 2026-05-12 15:56:45,970 - Update dx to 0.1997 Ang due to meas_crop, Npix = 120
# 2026-05-12 15:56:45,970 - Suggested probe_mask_k radius (RBF*2/Npix) changes to > 0.4341
# 2026-05-12 15:56:45,970 - Update dx to 0.0936 Ang due to meas_pad (mode = on_the_fly, padding_type = power), Npix = 256
# 2026-05-12 15:56:45,971 - Suggested probe_mask_k radius (RBF*2/Npix) changes to > 0.2035
# 2026-05-12 15:56:45,971 -
# 2026-05-12 15:56:45,972 - ### Setting init_variables dict ###
# 2026-05-12 15:56:45,972 - Derived values given input init_params:
# 2026-05-12 15:56:45,972 -   kv          = 300.0 kV
# 2026-05-12 15:56:45,973 -   wavelength  = 0.0197 Ang
# 2026-05-12 15:56:45,973 -   conv_angle  = 21.4 mrad
# 2026-05-12 15:56:45,973 -   Npix        = 256 px
# 2026-05-12 15:56:45,974 -   dk          = 0.0417 Ang^-1
# 2026-05-12 15:56:45,974 -   kMax        = 5.3422 Ang^-1
# 2026-05-12 15:56:45,974 -   da          = 0.8217 mrad
# 2026-05-12 15:56:45,974 -   angleMax    = 105.1737 mrad
# 2026-05-12 15:56:45,975 -   RBF         = 26.0445 px (Inferred from the given calibration, NOT necessarily from the loaded measurement data)
# 2026-05-12 15:56:45,975 -   n_alpha     = 4.9147 (# conv_angle)
# 2026-05-12 15:56:45,975 -   dx          = 0.0936 Ang, Nyquist-limited dmin = 2*dx = 0.1872 Ang
# 2026-05-12 15:56:45,976 -   Rayleigh-limited resolution  = 0.5612 Ang (0.61*lambda/alpha for focused probe )
# 2026-05-12 15:56:45,976 -   Real space probe extent = 23.9604 Ang
# 2026-05-12 15:56:45,976 -
# 2026-05-12 15:56:45,977 - ### Initializing probe ###
# 2026-05-12 15:56:45,977 - Loading probe from source = 'simu'
# 2026-05-12 15:56:45,977 - Using experimental parameters specified by 'init_params' for initial probe simulation.
# 2026-05-12 15:56:45,978 - Start simulating STEM probe
# 2026-05-12 15:56:45,987 -   kv          = 300.0 kV
# 2026-05-12 15:56:45,987 -   wavelength  = 0.0197 Ang
# 2026-05-12 15:56:45,987 -   conv_angle  = 21.4 mrad
# 2026-05-12 15:56:45,988 -   Npix        = 256 px
# 2026-05-12 15:56:45,988 -   dk          = 0.0417 Ang^-1
# 2026-05-12 15:56:45,988 -   kMax        = 5.3422 Ang^-1
# 2026-05-12 15:56:45,989 -   alpha_max   = 105.1700 mrad
# 2026-05-12 15:56:45,989 -   dx          = 0.0936 Ang, Nyquist-limited dmin = 2*dx = 0.1872 Ang
# 2026-05-12 15:56:45,989 -   Rayleigh-limited resolution  = 0.5612 Ang (0.61*lambda/alpha for focused probe )
# 2026-05-12 15:56:45,989 -   Real space probe extent = 23.9604 Ang
# 2026-05-12 15:56:45,990 - Start making mixed-state STEM probe with 4 incoherent probe modes
# 2026-05-12 15:56:46,006 - Relative power of probe modes = [0.94 0.02 0.02 0.02]
# 2026-05-12 15:56:46,006 - Loaded probe shape = (4, 256, 256), dtype = complex128
# 2026-05-12 15:56:46,007 - pmode_now: 4 and pmode_max: 4, leaving the pmode unchanged.
# 2026-05-12 15:56:46,010 - Orthogonalizing 4 pmodes
# 2026-05-12 15:56:46,016 - Sorting 4 pmodes by their intensities
# 2026-05-12 15:56:46,022 - sum(|probe_data|**2) = 2319.31, while meas.mean(0).sum() = 2319.31
# 2026-05-12 15:56:46,023 - probe                         (pmode, Ny, Nx) = complex64, (4, 256, 256)
# 2026-05-12 15:56:46,023 -
# 2026-05-12 15:56:46,023 - ### Initializing probe positions ###
# 2026-05-12 15:56:46,024 - Loading probe positions from source = 'simu'
# 2026-05-12 15:56:46,024 - Using experimental parameters specified by 'init_params' (dx, scan_step size, N_scan_slow, N_scan_fast) for initial position simulation.
# 2026-05-12 15:56:46,025 - Simulating probe positions with dx = 0.0936, scan_step_size = 0.4100, N_scan_fast = 64, N_scan_slow = 64
# 2026-05-12 15:56:46,035 - Applying Gaussian distributed random displacement with std = 0.15 px to scan positions
# 2026-05-12 15:56:46,037 - crop_pos                                (N,2) = int16, (4096, 2)
# 2026-05-12 15:56:46,037 - crop_pos 1st and last px coords (y,x)         = ([54, 54], [330, 330])
# 2026-05-12 15:56:46,038 - crop_pos extent (Ang)                         = [25.83226341 25.83226341]
# 2026-05-12 15:56:46,039 - probe_pos_shifts                        (N,2) = float32, (4096, 2)
# 2026-05-12 15:56:46,039 -
# 2026-05-12 15:56:46,040 - ### Initializing object ###
# 2026-05-12 15:56:46,040 - Loading object from source = 'simu'
# 2026-05-12 15:56:46,040 - Using experimental parameters specified by 'init_params' for initial object simulation.
# 2026-05-12 15:56:46,334 - omode_now: 1 and omode_max: 1, leaving the omode unchanged.
# 2026-05-12 15:56:46,348 - object                    (omode, Nz, Ny, Nx) = complex64, (1, 21, 639, 639)
# 2026-05-12 15:56:46,349 - object extent                 (Z, Y, X) (Ang) = [210.      59.8073  59.8073]
# 2026-05-12 15:56:46,349 -
# 2026-05-12 15:56:46,350 - ### Initializing omode_occu from 'uniform' ###
# 2026-05-12 15:56:46,350 - omode_occu                            (omode) = float32, (1,)
# 2026-05-12 15:56:46,350 -
# 2026-05-12 15:56:46,351 - ### Initializing H (Fresnel propagator) ###
# 2026-05-12 15:56:46,351 - Calculating H with probe_shape = [256. 256.] px, dx = 0.0936 Ang, slice_thickness = 10.0000 Ang, lambd = 0.0197 Ang
# 2026-05-12 15:56:46,355 - H                                    (Ky, Kx) = complex64, (256, 256)
# 2026-05-12 15:56:46,355 -
# 2026-05-12 15:56:46,355 - ### Initializing obj tilts from = 'simu' ###
# 2026-05-12 15:56:46,356 - Initialized obj_tilts with init_tilts = [[0.0, 0.0]] (theta_y, theta_x) mrad
# 2026-05-12 15:56:46,356 - obj_tilts                              (N, 2) = float32, (1, 2)
# 2026-05-12 15:56:46,356 -
# 2026-05-12 15:56:46,357 - ### Checking consistency between input params with the initialized variables ###
# 2026-05-12 15:56:46,357 - Npix, DP measurements, probe, and H shapes will be consistent as '256' during on-the-fly measurement padding
# 2026-05-12 15:56:46,357 - N_scans, len(meas), N_scan_slow*N_scan_fast, len(crop_pos), and len(probe_pos_shifts) are consistent as '4096'
# 2026-05-12 15:56:46,358 - obj.shape[0] is consistent with len(omode_occu) as '1'
# 2026-05-12 15:56:46,358 - obj.shape[1] is consistent with Nlayer as '21'
# 2026-05-12 15:56:46,360 - crop positions (yx_min=[54 54], yx_max=[586 586]) are well contained inside object canvas (Ny,Nx) = (639, 639).
# 2026-05-12 15:56:46,360 - obj_tilts is consistent with either 1 or N_scans
# 2026-05-12 15:56:46,360 - Pass the consistency check of initialized variables, initialization is done!
# 2026-05-12 15:56:46,360 -
# 2026-05-12 15:56:46,361 - ### Initializing loss function ###
# 2026-05-12 15:56:46,361 - Active loss types:
# 2026-05-12 15:56:46,361 -   loss_single : {'state': True, 'weight': 1.0, 'dp_pow': 0.5}
# 2026-05-12 15:56:46,362 -   loss_sparse : {'state': True, 'weight': 0.1, 'ln_order': 1}
# 2026-05-12 15:56:46,362 -
# 2026-05-12 15:56:46,363 - ### Initializing constraint function ###
# 2026-05-12 15:56:46,363 - Active constraint types:
# 2026-05-12 15:56:46,363 -   ortho_pmode   : {'start_iter': 1, 'step': 1, 'end_iter': None}
# 2026-05-12 15:56:46,364 -   fix_probe_int : {'start_iter': 1, 'step': 1, 'end_iter': None}
# 2026-05-12 15:56:46,364 -   obj_rblur     : {'start_iter': 1, 'step': 1, 'end_iter': None, 'obj_type': 'both', 'kernel_size': 5, 'std': 0.4}
# 2026-05-12 15:56:46,364 -   obj_zblur     : {'start_iter': 1, 'step': 1, 'end_iter': None, 'obj_type': 'both', 'kernel_size': 5, 'std': 1.0}
# 2026-05-12 15:56:46,365 -   mirrored_amp  : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.1, 'scale': 0.03, 'power': 4.0}
# 2026-05-12 15:56:46,365 -   obja_thresh   : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.0, 'thresh': [0.96, 1.04]}
# 2026-05-12 15:56:46,365 -   objp_postiv   : {'start_iter': 1, 'step': 1, 'end_iter': None, 'relax': 0.0}
# 2026-05-12 15:56:46,366 -
# 2026-05-12 15:56:46,366 - ### Done initializing PtyRADSolver ###
# 2026-05-12 15:56:46,366 -

# %%
ptycho_solver.run()

# Only `reconstruct` mode will return the final reconstructed model, because it's infeasible to store all models in `hypertune` mode and we don't know which model to return in `hypertune` mode
if not ptycho_solver.if_hypertune:
    model = ptycho_solver.reconstruct_results
# Out:
# 2026-05-12 15:56:46,558 - ### Starting the PtyRADSolver in reconstruct mode ###
# 2026-05-12 15:56:46,558 -
# 2026-05-12 15:56:46,559 - ### Initializing PtychoAD model ###
# 2026-05-12 15:56:46,746 - ### PtychoAD optimizable variables ###
# 2026-05-12 15:56:46,747 - obja            : torch.Size([1, 21, 639, 639])   , torch.float32   , device:cuda:0, grad:True , lr:1e-03
# 2026-05-12 15:56:46,748 - objp            : torch.Size([1, 21, 639, 639])   , torch.float32   , device:cuda:0, grad:True , lr:1e-03
# 2026-05-12 15:56:46,748 - obj_tilts       : torch.Size([1, 2])              , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-05-12 15:56:46,749 - slice_thickness : torch.Size([])                  , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-05-12 15:56:46,749 - probe           : torch.Size([4, 256, 256, 2])    , torch.float32   , device:cuda:0, grad:True , lr:1e-04
# 2026-05-12 15:56:46,749 - probe_pos_shifts: torch.Size([4096, 2])           , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2026-05-12 15:56:46,750 -
# 2026-05-12 15:56:46,750 - ### Optimizable variables statitsics ###
# 2026-05-12 15:56:46,751 - Total measurement values  : 58,982,400
# 2026-05-12 15:56:46,751 - Total optimizing variables: 17,673,770
# 2026-05-12 15:56:46,752 - Overdetermined ratio      : 3.34
# 2026-05-12 15:56:46,752 -
# 2026-05-12 15:56:46,753 - ### Model behavior ###
# 2026-05-12 15:56:46,753 - Obj preblur               : False
# 2026-05-12 15:56:46,753 - Tilt propagator           : False
# 2026-05-12 15:56:46,754 - Change slice thickness    : False
# 2026-05-12 15:56:46,754 - Sub-px probe shift        : False
# 2026-05-12 15:56:46,755 - Detector blur             : True
# 2026-05-12 15:56:46,755 - On-the-fly meas padding   : True
# 2026-05-12 15:56:46,755 - On-the-fly meas resample  : False
# 2026-05-12 15:56:46,755 - Solver type               : gmres1
# 2026-05-12 15:56:46,756 -
# 2026-05-12 15:56:46,800 - ### Done initializing PtychoAD model ###
# 2026-05-12 15:56:46,801 -
# 2026-05-12 15:56:46,801 - ### Creating PyTorch 'Adam' optimizer with configs = {} ###
# 2026-05-12 15:56:46,802 -
# 2026-05-12 15:56:46,802 - ### Generating indices, batches, and output_path ###
# 2026-05-12 15:56:46,807 - d90 = 91.000 px or 8.517 Ang
# 2026-05-12 15:56:46,807 - Selecting indices with the 'full' mode
# 2026-05-12 15:56:47,306 - Generated 128 'random' groups of ~32 scan positions in 0.000 sec
# 2026-05-12 15:56:47,533 - The effective batch size (i.e., how many probe positions are simultaneously used for 1 update of ptychographic parameters) is batch_size * grad_accumulation = 32 * 1 = 32
# 2026-05-12 15:56:47,534 - Original recon_dir_affixes = ['default']
# 2026-05-12 15:56:47,534 - Expanded recon_dir_affixes = ['indices', 'meas', 'batch', 'pmode', 'omode', 'nlayer', 'lr', 'model', 'constraint', 'loss', 'affine', 'tilt']
# 2026-05-12 15:56:47,545 - output_path = '/home/dnz75396/ptyrad/demo/output/batch32_gmres1/20260512_full_N4096_dp256_random32_p4_1obj_21slice_dz10_plr1e-4_oalr1e-3_oplr1e-3_dpblur1.0_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1' is generated!
# 2026-05-12 15:56:48,189 -
# 2026-05-12 15:56:48,190 - ### Successfully copy 'PSO_reconstruct.yml' to '/home/dnz75396/ptyrad/demo/output/batch32_gmres1/20260512_full_N4096_dp256_random32_p4_1obj_21slice_dz10_plr1e-4_oalr1e-3_oplr1e-3_dpblur1.0_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1' ###
# 2026-05-12 15:56:48,191 -
# 2026-05-12 15:56:48,192 - ### Log file is flushed (created) as /home/dnz75396/ptyrad/demo/output/batch32_gmres1/20260512_full_N4096_dp256_random32_p4_1obj_21slice_dz10_plr1e-4_oalr1e-3_oplr1e-3_dpblur1.0_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/20260512_155648_ptyrad_log.txt ###
# 2026-05-12 15:56:48,192 -
# 2026-05-12 15:56:48,193 - ### Start the PtyRAD iterative ptycho reconstruction ###
# 2026-05-12 15:56:48,193 -
# 2026-05-12 15:56:48,194 - Iter: 1, obja.requires_grad = True
# 2026-05-12 15:56:48,194 - Iter: 1, objp.requires_grad = True
# 2026-05-12 15:56:48,195 - Iter: 1, obj_tilts.requires_grad = False
# 2026-05-12 15:56:48,195 - Iter: 1, slice_thickness.requires_grad = False
# 2026-05-12 15:56:48,196 - Iter: 1, probe.requires_grad = True
# 2026-05-12 15:56:48,196 - Iter: 1, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:56:48,196 - Setting up PyTorch compiler with {'fullgraph': False, 'dynamic': None, 'backend': 'inductor', 'mode': 'default', 'options': None, 'disable': True}
# 2026-05-12 15:57:00,584 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 12.383 sec
# 2026-05-12 15:57:02,940 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.092 sec
# 2026-05-12 15:57:05,255 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.092 sec
# 2026-05-12 15:57:07,663 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.092 sec
# 2026-05-12 15:57:09,978 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.092 sec
# 2026-05-12 15:57:12,386 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:57:12,483 - Apply ortho pmode constraint at iter 1, relative pmode power = [0.921 0.049 0.019 0.011], probe int sum = 2323.8423
# 2026-05-12 15:57:12,485 - Apply fix probe int constraint at iter 1, probe int sum = 2319.3127
# 2026-05-12 15:57:12,486 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 1
# 2026-05-12 15:57:12,487 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 1
# 2026-05-12 15:57:12,681 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 1
# 2026-05-12 15:57:12,683 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 1
# 2026-05-12 15:57:12,704 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 1. obja range becomes (0.991, 1.010)
# 2026-05-12 15:57:12,706 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 1
# 2026-05-12 15:57:12,707 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 1. Original min = -0.091. objp range becomes (0.000, 0.090)
# 2026-05-12 15:57:12,708 - Iter: 1, Total Loss: 0.6267, loss_single: 0.6246, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0021, loss_simlar: 0.0000, in 24.507 sec
# 2026-05-12 15:57:13,004 - Saving summary figures for iter 1
# 2026-05-12 15:57:19,860 -
# 2026-05-12 15:57:19,862 - Iter: 2, obja.requires_grad = True
# 2026-05-12 15:57:19,862 - Iter: 2, objp.requires_grad = True
# 2026-05-12 15:57:19,862 - Iter: 2, obj_tilts.requires_grad = False
# 2026-05-12 15:57:19,863 - Iter: 2, slice_thickness.requires_grad = False
# 2026-05-12 15:57:19,863 - Iter: 2, probe.requires_grad = True
# 2026-05-12 15:57:19,864 - Iter: 2, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:57:19,959 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:57:22,276 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.092 sec
# 2026-05-12 15:57:24,593 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:57:27,003 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.092 sec
# 2026-05-12 15:57:29,319 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.092 sec
# 2026-05-12 15:57:31,730 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:57:31,734 - Apply ortho pmode constraint at iter 2, relative pmode power = [0.886 0.062 0.03  0.022], probe int sum = 2370.4419
# 2026-05-12 15:57:31,735 - Apply fix probe int constraint at iter 2, probe int sum = 2319.3130
# 2026-05-12 15:57:31,737 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 2
# 2026-05-12 15:57:31,738 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 2
# 2026-05-12 15:57:31,739 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 2
# 2026-05-12 15:57:31,740 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 2
# 2026-05-12 15:57:31,741 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 2. obja range becomes (0.993, 1.010)
# 2026-05-12 15:57:31,742 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 2
# 2026-05-12 15:57:31,743 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 2. Original min = -0.069. objp range becomes (0.000, 0.160)
# 2026-05-12 15:57:31,744 - Iter: 2, Total Loss: 0.4947, loss_single: 0.4928, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.879 sec
# 2026-05-12 15:57:32,038 - Saving summary figures for iter 2
# 2026-05-12 15:57:34,473 -
# 2026-05-12 15:57:34,474 - Iter: 3, obja.requires_grad = True
# 2026-05-12 15:57:34,474 - Iter: 3, objp.requires_grad = True
# 2026-05-12 15:57:34,475 - Iter: 3, obj_tilts.requires_grad = False
# 2026-05-12 15:57:34,475 - Iter: 3, slice_thickness.requires_grad = False
# 2026-05-12 15:57:34,476 - Iter: 3, probe.requires_grad = True
# 2026-05-12 15:57:34,476 - Iter: 3, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:57:34,573 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.095 sec
# 2026-05-12 15:57:36,893 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 15:57:39,213 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:57:41,624 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:57:43,942 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 15:57:46,355 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.092 sec
# 2026-05-12 15:57:46,359 - Apply ortho pmode constraint at iter 3, relative pmode power = [0.859 0.072 0.038 0.03 ], probe int sum = 2380.7793
# 2026-05-12 15:57:46,360 - Apply fix probe int constraint at iter 3, probe int sum = 2319.3130
# 2026-05-12 15:57:46,362 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 3
# 2026-05-12 15:57:46,363 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 3
# 2026-05-12 15:57:46,364 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 3
# 2026-05-12 15:57:46,366 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 3
# 2026-05-12 15:57:46,367 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 3. obja range becomes (0.993, 1.009)
# 2026-05-12 15:57:46,367 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 3
# 2026-05-12 15:57:46,368 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 3. Original min = -0.057. objp range becomes (0.000, 0.196)
# 2026-05-12 15:57:46,369 - Iter: 3, Total Loss: 0.4422, loss_single: 0.4402, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0021, loss_simlar: 0.0000, in 11.892 sec
# 2026-05-12 15:57:46,659 - Saving summary figures for iter 3
# 2026-05-12 15:57:49,088 -
# 2026-05-12 15:57:49,089 - Iter: 4, obja.requires_grad = True
# 2026-05-12 15:57:49,089 - Iter: 4, objp.requires_grad = True
# 2026-05-12 15:57:49,090 - Iter: 4, obj_tilts.requires_grad = False
# 2026-05-12 15:57:49,090 - Iter: 4, slice_thickness.requires_grad = False
# 2026-05-12 15:57:49,091 - Iter: 4, probe.requires_grad = True
# 2026-05-12 15:57:49,091 - Iter: 4, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:57:49,186 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:57:51,505 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.092 sec
# 2026-05-12 15:57:53,824 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:57:56,235 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:57:58,554 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.092 sec
# 2026-05-12 15:58:00,967 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.092 sec
# 2026-05-12 15:58:00,971 - Apply ortho pmode constraint at iter 4, relative pmode power = [0.841 0.079 0.044 0.036], probe int sum = 2377.5449
# 2026-05-12 15:58:00,972 - Apply fix probe int constraint at iter 4, probe int sum = 2319.3127
# 2026-05-12 15:58:00,974 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 4
# 2026-05-12 15:58:00,975 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 4
# 2026-05-12 15:58:00,976 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 4
# 2026-05-12 15:58:00,977 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 4
# 2026-05-12 15:58:00,978 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 4. obja range becomes (0.994, 1.008)
# 2026-05-12 15:58:00,979 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 4
# 2026-05-12 15:58:00,980 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 4. Original min = -0.063. objp range becomes (0.000, 0.209)
# 2026-05-12 15:58:00,981 - Iter: 4, Total Loss: 0.4248, loss_single: 0.4228, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.889 sec
# 2026-05-12 15:58:01,266 - Saving summary figures for iter 4
# 2026-05-12 15:58:04,359 -
# 2026-05-12 15:58:04,361 - Iter: 5, obja.requires_grad = True
# 2026-05-12 15:58:04,361 - Iter: 5, objp.requires_grad = True
# 2026-05-12 15:58:04,362 - Iter: 5, obj_tilts.requires_grad = False
# 2026-05-12 15:58:04,362 - Iter: 5, slice_thickness.requires_grad = False
# 2026-05-12 15:58:04,363 - Iter: 5, probe.requires_grad = True
# 2026-05-12 15:58:04,363 - Iter: 5, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:58:04,459 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:58:06,780 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 15:58:09,102 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:58:11,515 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:58:13,836 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.092 sec
# 2026-05-12 15:58:16,250 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:58:16,254 - Apply ortho pmode constraint at iter 5, relative pmode power = [0.83  0.083 0.047 0.04 ], probe int sum = 2365.4814
# 2026-05-12 15:58:16,255 - Apply fix probe int constraint at iter 5, probe int sum = 2319.3130
# 2026-05-12 15:58:16,257 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 5
# 2026-05-12 15:58:16,258 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 5
# 2026-05-12 15:58:16,259 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 5
# 2026-05-12 15:58:16,260 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 5
# 2026-05-12 15:58:16,262 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 5. obja range becomes (0.994, 1.008)
# 2026-05-12 15:58:16,262 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 5
# 2026-05-12 15:58:16,263 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 5. Original min = -0.066. objp range becomes (0.000, 0.213)
# 2026-05-12 15:58:16,264 - Iter: 5, Total Loss: 0.4171, loss_single: 0.4151, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.900 sec
# 2026-05-12 15:58:16,550 - Saving summary figures for iter 5
# 2026-05-12 15:58:19,002 -
# 2026-05-12 15:58:19,003 - Iter: 6, obja.requires_grad = True
# 2026-05-12 15:58:19,004 - Iter: 6, objp.requires_grad = True
# 2026-05-12 15:58:19,004 - Iter: 6, obj_tilts.requires_grad = False
# 2026-05-12 15:58:19,004 - Iter: 6, slice_thickness.requires_grad = False
# 2026-05-12 15:58:19,005 - Iter: 6, probe.requires_grad = True
# 2026-05-12 15:58:19,005 - Iter: 6, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:58:19,101 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:58:21,420 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.092 sec
# 2026-05-12 15:58:23,744 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:58:26,157 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:58:28,479 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 15:58:30,894 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:58:30,898 - Apply ortho pmode constraint at iter 6, relative pmode power = [0.825 0.085 0.049 0.041], probe int sum = 2353.1711
# 2026-05-12 15:58:30,899 - Apply fix probe int constraint at iter 6, probe int sum = 2319.3130
# 2026-05-12 15:58:30,900 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 6
# 2026-05-12 15:58:30,901 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 6
# 2026-05-12 15:58:30,903 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 6
# 2026-05-12 15:58:30,904 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 6
# 2026-05-12 15:58:30,905 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 6. obja range becomes (0.994, 1.008)
# 2026-05-12 15:58:30,906 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 6
# 2026-05-12 15:58:30,907 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 6. Original min = -0.065. objp range becomes (0.000, 0.228)
# 2026-05-12 15:58:30,907 - Iter: 6, Total Loss: 0.4138, loss_single: 0.4118, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.901 sec
# 2026-05-12 15:58:31,202 - Saving summary figures for iter 6
# 2026-05-12 15:58:34,249 -
# 2026-05-12 15:58:34,251 - Iter: 7, obja.requires_grad = True
# 2026-05-12 15:58:34,251 - Iter: 7, objp.requires_grad = True
# 2026-05-12 15:58:34,252 - Iter: 7, obj_tilts.requires_grad = False
# 2026-05-12 15:58:34,252 - Iter: 7, slice_thickness.requires_grad = False
# 2026-05-12 15:58:34,252 - Iter: 7, probe.requires_grad = True
# 2026-05-12 15:58:34,253 - Iter: 7, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:58:34,348 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.093 sec
# 2026-05-12 15:58:36,669 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 15:58:38,990 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:58:41,405 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:58:43,725 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.092 sec
# 2026-05-12 15:58:46,141 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:58:46,144 - Apply ortho pmode constraint at iter 7, relative pmode power = [0.822 0.086 0.05  0.042], probe int sum = 2347.6655
# 2026-05-12 15:58:46,145 - Apply fix probe int constraint at iter 7, probe int sum = 2319.3132
# 2026-05-12 15:58:46,146 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 7
# 2026-05-12 15:58:46,148 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 7
# 2026-05-12 15:58:46,149 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 7
# 2026-05-12 15:58:46,150 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 7
# 2026-05-12 15:58:46,151 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 7. obja range becomes (0.994, 1.008)
# 2026-05-12 15:58:46,152 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 7
# 2026-05-12 15:58:46,153 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 7. Original min = -0.063. objp range becomes (0.000, 0.242)
# 2026-05-12 15:58:46,154 - Iter: 7, Total Loss: 0.4117, loss_single: 0.4097, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.900 sec
# 2026-05-12 15:58:46,437 - Saving summary figures for iter 7
# 2026-05-12 15:58:48,865 -
# 2026-05-12 15:58:48,866 - Iter: 8, obja.requires_grad = True
# 2026-05-12 15:58:48,867 - Iter: 8, objp.requires_grad = True
# 2026-05-12 15:58:48,867 - Iter: 8, obj_tilts.requires_grad = False
# 2026-05-12 15:58:48,868 - Iter: 8, slice_thickness.requires_grad = False
# 2026-05-12 15:58:48,868 - Iter: 8, probe.requires_grad = True
# 2026-05-12 15:58:48,869 - Iter: 8, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:58:48,963 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.093 sec
# 2026-05-12 15:58:51,284 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 15:58:53,606 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:58:56,021 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:58:58,342 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 15:59:00,757 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:59:00,760 - Apply ortho pmode constraint at iter 8, relative pmode power = [0.82  0.086 0.051 0.043], probe int sum = 2346.2649
# 2026-05-12 15:59:00,761 - Apply fix probe int constraint at iter 8, probe int sum = 2319.3130
# 2026-05-12 15:59:00,762 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 8
# 2026-05-12 15:59:00,763 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 8
# 2026-05-12 15:59:00,764 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 8
# 2026-05-12 15:59:00,766 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 8
# 2026-05-12 15:59:00,767 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 8. obja range becomes (0.994, 1.009)
# 2026-05-12 15:59:00,767 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 8
# 2026-05-12 15:59:00,768 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 8. Original min = -0.065. objp range becomes (0.000, 0.252)
# 2026-05-12 15:59:00,769 - Iter: 8, Total Loss: 0.4101, loss_single: 0.4081, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.900 sec
# 2026-05-12 15:59:01,042 - Saving summary figures for iter 8
# 2026-05-12 15:59:03,929 -
# 2026-05-12 15:59:03,931 - Iter: 9, obja.requires_grad = True
# 2026-05-12 15:59:03,931 - Iter: 9, objp.requires_grad = True
# 2026-05-12 15:59:03,932 - Iter: 9, obj_tilts.requires_grad = False
# 2026-05-12 15:59:03,932 - Iter: 9, slice_thickness.requires_grad = False
# 2026-05-12 15:59:03,933 - Iter: 9, probe.requires_grad = True
# 2026-05-12 15:59:03,933 - Iter: 9, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:59:04,029 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:59:06,350 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.092 sec
# 2026-05-12 15:59:08,675 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:59:11,090 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.092 sec
# 2026-05-12 15:59:13,412 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 15:59:15,828 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:59:15,831 - Apply ortho pmode constraint at iter 9, relative pmode power = [0.817 0.087 0.052 0.044], probe int sum = 2346.6636
# 2026-05-12 15:59:15,833 - Apply fix probe int constraint at iter 9, probe int sum = 2319.3125
# 2026-05-12 15:59:15,834 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 9
# 2026-05-12 15:59:15,835 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 9
# 2026-05-12 15:59:15,836 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 9
# 2026-05-12 15:59:15,838 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 9
# 2026-05-12 15:59:15,839 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 9. obja range becomes (0.994, 1.009)
# 2026-05-12 15:59:15,839 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 9
# 2026-05-12 15:59:15,840 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 9. Original min = -0.066. objp range becomes (0.000, 0.258)
# 2026-05-12 15:59:15,841 - Iter: 9, Total Loss: 0.4087, loss_single: 0.4067, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0020, loss_simlar: 0.0000, in 11.907 sec
# 2026-05-12 15:59:16,125 - Saving summary figures for iter 9
# 2026-05-12 15:59:18,603 -
# 2026-05-12 15:59:18,604 - Iter: 10, obja.requires_grad = True
# 2026-05-12 15:59:18,604 - Iter: 10, objp.requires_grad = True
# 2026-05-12 15:59:18,605 - Iter: 10, obj_tilts.requires_grad = False
# 2026-05-12 15:59:18,605 - Iter: 10, slice_thickness.requires_grad = False
# 2026-05-12 15:59:18,606 - Iter: 10, probe.requires_grad = True
# 2026-05-12 15:59:18,606 - Iter: 10, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:59:18,702 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:59:21,023 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.092 sec
# 2026-05-12 15:59:23,344 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:59:25,760 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:59:28,081 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 15:59:30,497 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:59:30,500 - Apply ortho pmode constraint at iter 10, relative pmode power = [0.814 0.088 0.053 0.045], probe int sum = 2348.0344
# 2026-05-12 15:59:30,502 - Apply fix probe int constraint at iter 10, probe int sum = 2319.3130
# 2026-05-12 15:59:30,503 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 10
# 2026-05-12 15:59:30,504 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 10
# 2026-05-12 15:59:30,505 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 10
# 2026-05-12 15:59:30,507 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 10
# 2026-05-12 15:59:30,508 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 10. obja range becomes (0.994, 1.009)
# 2026-05-12 15:59:30,509 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 10
# 2026-05-12 15:59:30,510 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 10. Original min = -0.066. objp range becomes (0.000, 0.269)
# 2026-05-12 15:59:30,511 - Iter: 10, Total Loss: 0.4074, loss_single: 0.4054, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0021, loss_simlar: 0.0000, in 11.904 sec
# 2026-05-12 15:59:30,787 - Saving summary figures for iter 10
# 2026-05-12 15:59:33,765 -
# 2026-05-12 15:59:33,767 - Iter: 11, obja.requires_grad = True
# 2026-05-12 15:59:33,767 - Iter: 11, objp.requires_grad = True
# 2026-05-12 15:59:33,767 - Iter: 11, obj_tilts.requires_grad = False
# 2026-05-12 15:59:33,768 - Iter: 11, slice_thickness.requires_grad = False
# 2026-05-12 15:59:33,768 - Iter: 11, probe.requires_grad = True
# 2026-05-12 15:59:33,769 - Iter: 11, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:59:33,864 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:59:36,185 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 15:59:38,509 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:59:40,925 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.092 sec
# 2026-05-12 15:59:43,252 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 15:59:45,667 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 15:59:45,670 - Apply ortho pmode constraint at iter 11, relative pmode power = [0.81  0.089 0.055 0.046], probe int sum = 2350.0874
# 2026-05-12 15:59:45,672 - Apply fix probe int constraint at iter 11, probe int sum = 2319.3130
# 2026-05-12 15:59:45,673 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 11
# 2026-05-12 15:59:45,674 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 11
# 2026-05-12 15:59:45,675 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 11
# 2026-05-12 15:59:45,677 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 11
# 2026-05-12 15:59:45,678 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 11. obja range becomes (0.994, 1.009)
# 2026-05-12 15:59:45,678 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 11
# 2026-05-12 15:59:45,679 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 11. Original min = -0.066. objp range becomes (0.000, 0.278)
# 2026-05-12 15:59:45,680 - Iter: 11, Total Loss: 0.4062, loss_single: 0.4041, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0021, loss_simlar: 0.0000, in 11.911 sec
# 2026-05-12 15:59:45,964 - Saving summary figures for iter 11
# 2026-05-12 15:59:48,436 -
# 2026-05-12 15:59:48,437 - Iter: 12, obja.requires_grad = True
# 2026-05-12 15:59:48,438 - Iter: 12, objp.requires_grad = True
# 2026-05-12 15:59:48,438 - Iter: 12, obj_tilts.requires_grad = False
# 2026-05-12 15:59:48,439 - Iter: 12, slice_thickness.requires_grad = False
# 2026-05-12 15:59:48,439 - Iter: 12, probe.requires_grad = True
# 2026-05-12 15:59:48,440 - Iter: 12, probe_pos_shifts.requires_grad = False
# 2026-05-12 15:59:48,535 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 15:59:50,856 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 15:59:53,180 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 15:59:55,596 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 15:59:57,918 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 16:00:00,335 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 16:00:00,339 - Apply ortho pmode constraint at iter 12, relative pmode power = [0.806 0.091 0.056 0.047], probe int sum = 2352.6587
# 2026-05-12 16:00:00,340 - Apply fix probe int constraint at iter 12, probe int sum = 2319.3130
# 2026-05-12 16:00:00,341 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 12
# 2026-05-12 16:00:00,342 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 12
# 2026-05-12 16:00:00,344 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 12
# 2026-05-12 16:00:00,345 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 12
# 2026-05-12 16:00:00,346 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 12. obja range becomes (0.994, 1.009)
# 2026-05-12 16:00:00,347 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 12
# 2026-05-12 16:00:00,348 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 12. Original min = -0.066. objp range becomes (0.000, 0.285)
# 2026-05-12 16:00:00,348 - Iter: 12, Total Loss: 0.4049, loss_single: 0.4028, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0021, loss_simlar: 0.0000, in 11.908 sec
# 2026-05-12 16:00:00,625 - Saving summary figures for iter 12
# 2026-05-12 16:00:03,075 -
# 2026-05-12 16:00:03,077 - Iter: 13, obja.requires_grad = True
# 2026-05-12 16:00:03,078 - Iter: 13, objp.requires_grad = True
# 2026-05-12 16:00:03,078 - Iter: 13, obj_tilts.requires_grad = False
# 2026-05-12 16:00:03,079 - Iter: 13, slice_thickness.requires_grad = False
# 2026-05-12 16:00:03,079 - Iter: 13, probe.requires_grad = True
# 2026-05-12 16:00:03,080 - Iter: 13, probe_pos_shifts.requires_grad = False
# 2026-05-12 16:00:03,175 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 16:00:05,499 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 16:00:07,823 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 16:00:10,238 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 16:00:12,559 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 16:00:14,974 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 16:00:14,978 - Apply ortho pmode constraint at iter 13, relative pmode power = [0.801 0.092 0.058 0.049], probe int sum = 2355.5830
# 2026-05-12 16:00:14,979 - Apply fix probe int constraint at iter 13, probe int sum = 2319.3132
# 2026-05-12 16:00:14,980 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 13
# 2026-05-12 16:00:14,982 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 13
# 2026-05-12 16:00:14,983 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 13
# 2026-05-12 16:00:14,984 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 13
# 2026-05-12 16:00:14,985 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 13. obja range becomes (0.994, 1.009)
# 2026-05-12 16:00:14,986 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 13
# 2026-05-12 16:00:14,987 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 13. Original min = -0.066. objp range becomes (0.000, 0.293)
# 2026-05-12 16:00:14,988 - Iter: 13, Total Loss: 0.4037, loss_single: 0.4015, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0021, loss_simlar: 0.0000, in 11.907 sec
# 2026-05-12 16:00:15,265 - Saving summary figures for iter 13
# 2026-05-12 16:00:18,336 -
# 2026-05-12 16:00:18,337 - Iter: 14, obja.requires_grad = True
# 2026-05-12 16:00:18,337 - Iter: 14, objp.requires_grad = True
# 2026-05-12 16:00:18,338 - Iter: 14, obj_tilts.requires_grad = False
# 2026-05-12 16:00:18,338 - Iter: 14, slice_thickness.requires_grad = False
# 2026-05-12 16:00:18,339 - Iter: 14, probe.requires_grad = True
# 2026-05-12 16:00:18,339 - Iter: 14, probe_pos_shifts.requires_grad = False
# 2026-05-12 16:00:18,435 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 16:00:20,755 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 16:00:23,077 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 16:00:25,491 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# 2026-05-12 16:00:27,814 - Done batch 102 with 32 indices ([3342, 354, 2284, 1029, 4001]...) in 0.093 sec
# 2026-05-12 16:00:30,235 - Done batch 128 with 32 indices ([365, 2867, 3256, 1357, 2076]...) in 0.093 sec
# 2026-05-12 16:00:30,239 - Apply ortho pmode constraint at iter 14, relative pmode power = [0.795 0.094 0.06  0.051], probe int sum = 2358.6479
# 2026-05-12 16:00:30,240 - Apply fix probe int constraint at iter 14, probe int sum = 2319.3125
# 2026-05-12 16:00:30,241 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on obja at iter 14
# 2026-05-12 16:00:30,242 - Apply lateral (y,x) Gaussian blur with std = 0.4 px on objp at iter 14
# 2026-05-12 16:00:30,244 - Apply z-direction Gaussian blur with std = 1.0 px on obja at iter 14
# 2026-05-12 16:00:30,245 - Apply z-direction Gaussian blur with std = 1.0 px on objp at iter 14
# 2026-05-12 16:00:30,246 - Apply relaxed (0.1*obj + (0.9*obj_new)) mirrored amplitude constraint with scale = 0.03 and power = 4.0 on obja at iter 14. obja range becomes (0.994, 1.009)
# 2026-05-12 16:00:30,247 - Apply hard threshold constraint with thresh = [0.96, 1.04] on obja at iter 14
# 2026-05-12 16:00:30,248 - Apply hard positivity constraint on objp with 'clip_neg' mode at iter 14. Original min = -0.065. objp range becomes (0.000, 0.302)
# 2026-05-12 16:00:30,249 - Iter: 14, Total Loss: 0.4024, loss_single: 0.4002, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0022, loss_simlar: 0.0000, in 11.908 sec
# 2026-05-12 16:00:30,487 - Saving summary figures for iter 14
# 2026-05-12 16:00:32,971 -
# 2026-05-12 16:00:32,972 - Iter: 15, obja.requires_grad = True
# 2026-05-12 16:00:32,973 - Iter: 15, objp.requires_grad = True
# 2026-05-12 16:00:32,973 - Iter: 15, obj_tilts.requires_grad = False
# 2026-05-12 16:00:32,973 - Iter: 15, slice_thickness.requires_grad = False
# 2026-05-12 16:00:32,974 - Iter: 15, probe.requires_grad = True
# 2026-05-12 16:00:32,974 - Iter: 15, probe_pos_shifts.requires_grad = False
# 2026-05-12 16:00:33,069 - Done batch 1 with 32 indices ([560, 191, 3276, 2050, 139]...) in 0.094 sec
# 2026-05-12 16:00:35,394 - Done batch 26 with 32 indices ([926, 422, 951, 484, 1467]...) in 0.093 sec
# 2026-05-12 16:00:37,719 - Done batch 51 with 32 indices ([1173, 2566, 1989, 2638, 3323]...) in 0.093 sec
# 2026-05-12 16:00:40,136 - Done batch 77 with 32 indices ([280, 2503, 3613, 3433, 2837]...) in 0.093 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ptycho_solver.run()
#       3 # Only `reconstruct` mode will return the final reconstructed model, because it's infeasible to store all models in `hypertune` mode and we don't know which model to return in `hypertune` mode
#       4 if not ptycho_solver.if_hypertune:
#
# File ~/ptyrad/src/ptyrad/reconstruction.py:357, in PtyRADSolver.run(self)
#     355     self.hypertune()
#     356 else:
# --> 357     self.reconstruct()
#     358 end_t = time_sync()
#     359 solver_t = end_t - start_t
#
# File ~/ptyrad/src/ptyrad/reconstruction.py:196, in PtyRADSolver.reconstruct(self)
#     192 if logger is not None and logger.flush_file:
#     193     logger.flush_to_file(
#     194         log_dir=output_path
#     195     )  # Note that output_path can be None, and there's an internal flag of self.flush_file controls the actual file creation
# --> 196 recon_loop(
#     197     model,
#     198     self.init,
#     199     params,
#     200     optimizer,
#     201     self.loss_fn,
#     202     self.constraint_fn,
#     203     indices,
#     204     batches,
#     205     output_path,
#     206     acc=self.accelerator,
#     207 )
#     208 self.reconstruct_results = model
#     209 self.optimizer = optimizer
#
# File ~/ptyrad/src/ptyrad/reconstruction.py:884, in recon_loop(model, init, params, optimizer, loss_fn, constraint_fn, indices, batches, output_path, acc)
#     881     torch._dynamo.reset()
#     882     recon_step_compiled = torch.compile(recon_step, **compiler_configs)
# --> 884 batch_losses = recon_step_compiled(
#     885     batches,
#     886     grad_accumulation,
#     887     model,
#     888     optimizer,
#     889     loss_fn,
#     890     constraint_fn,
#     891     niter,
#     892     verbose=verbose,
#     893     acc=acc,
#     894 )
#     896 # Only log the main process
#     897 if acc is None or acc.is_main_process:
#     898     ## Saving intermediate results
#
# File ~/ptyrad/src/ptyrad/reconstruction.py:1028, in recon_step(batches, grad_accumulation, model, optimizer, loss_fn, constraint_fn, niter, verbose, acc)
#    1025 start_batch_t = time_sync()
#    1027 # Compute forward pass and loss (wrapped in autocast if accelerate is enabled)
# -> 1028 loss_batch, losses = compute_loss(batch, model, model_instance, loss_fn, acc)
#    1030 # Normalize the `loss_batch`` before populating the gradients
#    1031 # We only want to scale the `loss_batch` so the grad/update is scaled accordingly
#    1032 # while keeping `losses` to be batch-size-independent for logging purpose
#    1033 loss_batch = loss_batch / grad_accumulation
#
# File ~/ptyrad/src/ptyrad/reconstruction.py:1109, in compute_loss(batch, model, model_instance, loss_fn, acc)
#    1107     measured_DP = model_instance.get_measurements(batch)
#    1108     object_patches = model_instance._current_object_patches
# -> 1109     loss_batch, losses = loss_fn(
#    1110         model_DP, measured_DP, object_patches, model_instance.omode_occu
#    1111     )
#    1113 return loss_batch, losses
#
# File ~/ptyrad/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ptyrad/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ptyrad/src/ptyrad/losses.py:182, in CombinedLoss.forward(self, model_DP, measured_DP, object_patches, omode_occu)
#     180 losses.append(self.get_loss_single(model_DP, measured_DP))
#     181 losses.append(self.get_loss_poissn(model_DP, measured_DP))
# --> 182 losses.append(self.get_loss_pacbed(model_DP, measured_DP))
#     183 losses.append(self.get_loss_sparse(object_patches[..., 1], omode_occu))
#     184 losses.append(self.get_loss_simlar(object_patches, omode_occu))
#
# File ~/ptyrad/src/ptyrad/losses.py:109, in CombinedLoss.get_loss_pacbed(self, model_DP, measured_DP)
#     107     loss_pacbed *= pacbed_params["weight"]
#     108 else:
# --> 109     loss_pacbed = torch.tensor(0, dtype=torch.float32, device=self.device)
#     110 return loss_pacbed
#
# KeyboardInterrupt:
